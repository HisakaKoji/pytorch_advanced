# %% [markdown]
# # 5.1-2 DCGANの作成
#
# - 本ファイルでは、DCGANのネットワークを実装とDCGANの学習をします。

# %%
# !git clone https://github.com/HisakaKoji/pytorch_advanced.git
# Out:
# Cloning into 'pytorch_advanced'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 459 (delta 10), reused 0 (delta 0), pack-reused 443
# Receiving objects: 100% (459/459), 14.73 MiB | 19.74 MiB/s, done.
# Resolving deltas: 100% (245/245), done.

# %%
# %cd pytorch_advanced/5_gan_generation/
# Out:
# /content/pytorch_advanced/5_gan_generation

# %%
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# %%
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.2.post1

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.6/dist-packages (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (0.14.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.18.3)

# %%
# MNISTの手書き数字画像をダウンロードし読み込みます（2分ほど時間がかかります）
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  
# data_homeは保存先を指定します

# %%
# データの取り出し
X = mnist.data
y = mnist.target

# %%
# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))
# Out:
# この画像データのラベルは5です

# %%
# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %% [markdown]
# # 5.1 学習目標
#
# 1.	Generatorが画像を生成するためにどのようなニューラルネットワークの構造になっているのかを理解する
# 2.	Discriminatorが画像の識別をするためにどのようなニューラルネットワークの構造になっているのかを理解する
# 3.	GANの一般的な損失関数の形とニューラルネットワークの学習の流れを理解する
# 4.	DCGANのネットワークを実装できるようになる

# %% [markdown]
# # 5.2 学習目標
#
# 1.	GANの損失関数の形を理解する
# 2.	DCGANを実装し、手書き数字画像が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # 転置畳み込みの例

# %%
input = torch.tensor([[[[1., 1.], [2., 2.]]]])
print("入力データ")
print(input)
print("-----")

print("通常の畳み込み")
m = nn.Conv2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))

print("-----")
print("転置畳み込み")
m = nn.ConvTranspose2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))
# Out:
# 入力データ
# tensor([[[[1., 1.],
#           [2., 2.]]]])
# -----
# 通常の畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], grad_fn=<CopySlices>)
# 出力
# tensor([[[[17.]]]], grad_fn=<MkldnnConvolutionBackward>)
# -----
# 転置畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], grad_fn=<CopySlices>)
# 出力
# tensor([[[[ 1.,  3.,  2.],
#           [ 5., 13.,  8.],
#           [ 6., 14.,  8.]]]], grad_fn=<SlowConvTranspose2DBackward>)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5014]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # 6.2へ

# %% [markdown]
# # GANの損失関数

# %%
# Dの誤差関数のイメージ実装
# maximize log(D(x)) + log(1 - D(G(z)))


# ※ xが未定義なので動作はエラーになります
#---------------


# 正解ラベルを作成
mini_batch_size = 2
label_real = torch.full((mini_batch_size,), 1)

# 偽ラベルを作成
label_fake = torch.full((mini_batch_size,), 0)

# 誤差関数を定義
criterion = nn.BCEWithLogitsLoss(reduction='mean')

# 真の画像を判定
d_out_real = D(x)

# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
d_loss_real = criterion(d_out_real.view(-1), label_real)
d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
d_loss = d_loss_real + d_loss_fake
# Out:
# /pytorch/aten/src/ATen/native/TensorFactories.cpp:361: UserWarning: Deprecation warning: In a future PyTorch release torch.full will no longer return tensors of floating dtype by default. Instead, a bool fill_value will return a tensor of torch.bool dtype, and an integral fill_value will return a tensor of torch.long dtype. Set the optional `dtype` or `out` arguments to suppress this warning.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b63842ae8769> in <module>()
#       9
#      10 # 真の画像を判定
# ---> 11 d_out_real = D(x)
#      12
#      13 # 偽の画像を生成して判定
#
# NameError: name 'x' is not defined

# %%
# Gの誤差関数のイメージ実装
# maximize log(D(G(z)))


# ※ xが未定義なので動作はエラーになります
#---------------


# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
g_loss = criterion(d_out_fake.view(-1), label_real)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習させる

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
# 学習・検証を実行する
# 6分ほどかかる
num_epochs = 200
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/200
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0714 ||Epoch_G_Loss:0.2399
# timer:  0.6609 sec.
# -------------
# Epoch 1/200
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0181 ||Epoch_G_Loss:0.5000
# timer:  0.4237 sec.
# -------------
# Epoch 2/200
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.6190
# timer:  0.4299 sec.
# -------------
# Epoch 3/200
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0921 ||Epoch_G_Loss:0.2186
# timer:  0.4217 sec.
# -------------
# Epoch 4/200
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0019 ||Epoch_G_Loss:0.5455
# timer:  0.4246 sec.
# -------------
# Epoch 5/200
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.2691 ||Epoch_G_Loss:0.5523
# timer:  0.4254 sec.
# -------------
# Epoch 6/200
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.1463 ||Epoch_G_Loss:0.0600
# timer:  0.4235 sec.
# -------------
# Epoch 7/200
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0930 ||Epoch_G_Loss:0.0845
# timer:  0.4250 sec.
# -------------
# Epoch 8/200
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0739 ||Epoch_G_Loss:0.1158
# timer:  0.4261 sec.
# -------------
# Epoch 9/200
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0856 ||Epoch_G_Loss:0.1541
# timer:  0.4320 sec.
# -------------
# Epoch 10/200
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0226 ||Epoch_G_Loss:0.2482
# timer:  0.4242 sec.
# -------------
# Epoch 11/200
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0253 ||Epoch_G_Loss:0.3706
# timer:  0.4221 sec.
# -------------
# Epoch 12/200
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.4746
# timer:  0.4249 sec.
# -------------
# Epoch 13/200
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.2450 ||Epoch_G_Loss:0.5915
# timer:  0.4270 sec.
# -------------
# Epoch 14/200
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0799 ||Epoch_G_Loss:0.2000
# timer:  0.4264 sec.
# -------------
# Epoch 15/200
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0176 ||Epoch_G_Loss:0.3303
# timer:  0.4335 sec.
# -------------
# Epoch 16/200
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0657 ||Epoch_G_Loss:0.3684
# timer:  0.4303 sec.
# -------------
# Epoch 17/200
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0190 ||Epoch_G_Loss:0.4057
# timer:  0.4223 sec.
# -------------
# Epoch 18/200
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0914 ||Epoch_G_Loss:0.3802
# timer:  0.4241 sec.
# -------------
# Epoch 19/200
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.2308 ||Epoch_G_Loss:0.4293
# timer:  0.4268 sec.
# -------------
# Epoch 20/200
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0389 ||Epoch_G_Loss:0.2713
# timer:  0.4250 sec.
# -------------
# Epoch 21/200
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0776 ||Epoch_G_Loss:0.2386
# timer:  0.4305 sec.
# -------------
# Epoch 22/200
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0664 ||Epoch_G_Loss:0.3394
# timer:  0.4180 sec.
# -------------
# Epoch 23/200
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.1565 ||Epoch_G_Loss:0.2659
# timer:  0.4243 sec.
# -------------
# Epoch 24/200
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1075 ||Epoch_G_Loss:0.2149
# timer:  0.4272 sec.
# -------------
# Epoch 25/200
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0344 ||Epoch_G_Loss:0.2560
# timer:  0.4180 sec.
# -------------
# Epoch 26/200
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.1063 ||Epoch_G_Loss:0.2432
# timer:  0.4234 sec.
# -------------
# Epoch 27/200
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0926 ||Epoch_G_Loss:0.2086
# timer:  0.4229 sec.
# -------------
# Epoch 28/200
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.1681 ||Epoch_G_Loss:0.2142
# timer:  0.4310 sec.
# -------------
# Epoch 29/200
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.0813 ||Epoch_G_Loss:0.2562
# timer:  0.4216 sec.
# -------------
# Epoch 30/200
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0803 ||Epoch_G_Loss:0.2022
# timer:  0.4211 sec.
# -------------
# Epoch 31/200
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0936 ||Epoch_G_Loss:0.2312
# timer:  0.4243 sec.
# -------------
# Epoch 32/200
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1241 ||Epoch_G_Loss:0.2023
# timer:  0.4241 sec.
# -------------
# Epoch 33/200
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1083 ||Epoch_G_Loss:0.1992
# timer:  0.4249 sec.
# -------------
# Epoch 34/200
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0859 ||Epoch_G_Loss:0.2639
# timer:  0.4208 sec.
# -------------
# Epoch 35/200
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1459 ||Epoch_G_Loss:0.1365
# timer:  0.4258 sec.
# -------------
# Epoch 36/200
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1140 ||Epoch_G_Loss:0.1719
# timer:  0.4198 sec.
# -------------
# Epoch 37/200
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.1114 ||Epoch_G_Loss:0.1949
# timer:  0.4194 sec.
# -------------
# Epoch 38/200
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1069 ||Epoch_G_Loss:0.1885
# timer:  0.4244 sec.
# -------------
# Epoch 39/200
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1055 ||Epoch_G_Loss:0.2132
# timer:  0.4248 sec.
# -------------
# Epoch 40/200
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.1414 ||Epoch_G_Loss:0.2294
# timer:  0.4274 sec.
# -------------
# Epoch 41/200
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0724 ||Epoch_G_Loss:0.2016
# timer:  0.4224 sec.
# -------------
# Epoch 42/200
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.1768
# timer:  0.4277 sec.
# -------------
# Epoch 43/200
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1065 ||Epoch_G_Loss:0.1829
# timer:  0.4290 sec.
# -------------
# Epoch 44/200
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.1115 ||Epoch_G_Loss:0.1514
# timer:  0.4221 sec.
# -------------
# Epoch 45/200
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1140 ||Epoch_G_Loss:0.1602
# timer:  0.4277 sec.
# -------------
# Epoch 46/200
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.1056 ||Epoch_G_Loss:0.1473
# timer:  0.4216 sec.
# -------------
# Epoch 47/200
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1166 ||Epoch_G_Loss:0.1561
# timer:  0.4243 sec.
# -------------
# Epoch 48/200
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1425
# timer:  0.4210 sec.
# -------------
# Epoch 49/200
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1184 ||Epoch_G_Loss:0.1441
# timer:  0.4235 sec.
# -------------
# Epoch 50/200
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.1373
# timer:  0.4190 sec.
# -------------
# Epoch 51/200
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1300 ||Epoch_G_Loss:0.1323
# timer:  0.4176 sec.
# -------------
# Epoch 52/200
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1223 ||Epoch_G_Loss:0.1455
# timer:  0.4265 sec.
# -------------
# Epoch 53/200
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1500
# timer:  0.4175 sec.
# -------------
# Epoch 54/200
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1151 ||Epoch_G_Loss:0.1315
# timer:  0.4266 sec.
# -------------
# Epoch 55/200
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1244 ||Epoch_G_Loss:0.1686
# timer:  0.4268 sec.
# -------------
# Epoch 56/200
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1133 ||Epoch_G_Loss:0.1237
# timer:  0.4189 sec.
# -------------
# Epoch 57/200
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.1541
# timer:  0.4249 sec.
# -------------
# Epoch 58/200
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1040 ||Epoch_G_Loss:0.1384
# timer:  0.4233 sec.
# -------------
# Epoch 59/200
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1098 ||Epoch_G_Loss:0.1564
# timer:  0.4220 sec.
# -------------
# Epoch 60/200
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1520
# timer:  0.4207 sec.
# -------------
# Epoch 61/200
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1591
# timer:  0.4228 sec.
# -------------
# Epoch 62/200
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0979 ||Epoch_G_Loss:0.1499
# timer:  0.4247 sec.
# -------------
# Epoch 63/200
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1644
# timer:  0.4199 sec.
# -------------
# Epoch 64/200
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1108 ||Epoch_G_Loss:0.1608
# timer:  0.4343 sec.
# -------------
# Epoch 65/200
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.1147 ||Epoch_G_Loss:0.1619
# timer:  0.4180 sec.
# -------------
# Epoch 66/200
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0879 ||Epoch_G_Loss:0.1718
# timer:  0.4263 sec.
# -------------
# Epoch 67/200
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.1157 ||Epoch_G_Loss:0.1389
# timer:  0.4232 sec.
# -------------
# Epoch 68/200
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.1615
# timer:  0.4206 sec.
# -------------
# Epoch 69/200
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1879
# timer:  0.4232 sec.
# -------------
# Epoch 70/200
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.1592
# timer:  0.4231 sec.
# -------------
# Epoch 71/200
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1000 ||Epoch_G_Loss:0.1757
# timer:  0.4306 sec.
# -------------
# Epoch 72/200
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0958 ||Epoch_G_Loss:0.1708
# timer:  0.4196 sec.
# -------------
# Epoch 73/200
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1747
# timer:  0.4247 sec.
# -------------
# Epoch 74/200
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0901 ||Epoch_G_Loss:0.1728
# timer:  0.4242 sec.
# -------------
# Epoch 75/200
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0931 ||Epoch_G_Loss:0.1867
# timer:  0.4208 sec.
# -------------
# Epoch 76/200
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.1099 ||Epoch_G_Loss:0.1756
# timer:  0.4262 sec.
# -------------
# Epoch 77/200
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0875 ||Epoch_G_Loss:0.1961
# timer:  0.4200 sec.
# -------------
# Epoch 78/200
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1651
# timer:  0.4285 sec.
# -------------
# Epoch 79/200
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1959
# timer:  0.4229 sec.
# -------------
# Epoch 80/200
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.1712
# timer:  0.4206 sec.
# -------------
# Epoch 81/200
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.1096 ||Epoch_G_Loss:0.1728
# timer:  0.4241 sec.
# -------------
# Epoch 82/200
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.1982
# timer:  0.4204 sec.
# -------------
# Epoch 83/200
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.1653
# timer:  0.4246 sec.
# -------------
# Epoch 84/200
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1980
# timer:  0.4237 sec.
# -------------
# Epoch 85/200
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.1871
# timer:  0.4244 sec.
# -------------
# Epoch 86/200
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0805 ||Epoch_G_Loss:0.1969
# timer:  0.4231 sec.
# -------------
# Epoch 87/200
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0980 ||Epoch_G_Loss:0.1794
# timer:  0.4194 sec.
# -------------
# Epoch 88/200
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0918 ||Epoch_G_Loss:0.1934
# timer:  0.4271 sec.
# -------------
# Epoch 89/200
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.2067
# timer:  0.4274 sec.
# -------------
# Epoch 90/200
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.1006 ||Epoch_G_Loss:0.1577
# timer:  0.4225 sec.
# -------------
# Epoch 91/200
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0949 ||Epoch_G_Loss:0.1865
# timer:  0.4234 sec.
# -------------
# Epoch 92/200
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0856 ||Epoch_G_Loss:0.1699
# timer:  0.4256 sec.
# -------------
# Epoch 93/200
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0930 ||Epoch_G_Loss:0.1803
# timer:  0.4241 sec.
# -------------
# Epoch 94/200
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.2012
# timer:  0.4288 sec.
# -------------
# Epoch 95/200
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0835 ||Epoch_G_Loss:0.1792
# timer:  0.4307 sec.
# -------------
# Epoch 96/200
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0841 ||Epoch_G_Loss:0.2036
# timer:  0.4159 sec.
# -------------
# Epoch 97/200
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0835 ||Epoch_G_Loss:0.1864
# timer:  0.4258 sec.
# -------------
# Epoch 98/200
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.2217
# timer:  0.4262 sec.
# -------------
# Epoch 99/200
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0922 ||Epoch_G_Loss:0.1804
# timer:  0.4242 sec.
# -------------
# Epoch 100/200
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0833 ||Epoch_G_Loss:0.2056
# timer:  0.4265 sec.
# -------------
# Epoch 101/200
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.1984
# timer:  0.4238 sec.
# -------------
# Epoch 102/200
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0749 ||Epoch_G_Loss:0.2464
# timer:  0.4211 sec.
# -------------
# Epoch 103/200
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0950 ||Epoch_G_Loss:0.1613
# timer:  0.4241 sec.
# -------------
# Epoch 104/200
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0864 ||Epoch_G_Loss:0.2039
# timer:  0.4208 sec.
# -------------
# Epoch 105/200
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0849 ||Epoch_G_Loss:0.2042
# timer:  0.4258 sec.
# -------------
# Epoch 106/200
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0753 ||Epoch_G_Loss:0.2052
# timer:  0.4212 sec.
# -------------
# Epoch 107/200
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0893 ||Epoch_G_Loss:0.2077
# timer:  0.4244 sec.
# -------------
# Epoch 108/200
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0850 ||Epoch_G_Loss:0.1917
# timer:  0.4248 sec.
# -------------
# Epoch 109/200
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0896 ||Epoch_G_Loss:0.2232
# timer:  0.4215 sec.
# -------------
# Epoch 110/200
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0753 ||Epoch_G_Loss:0.2030
# timer:  0.4208 sec.
# -------------
# Epoch 111/200
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0869 ||Epoch_G_Loss:0.2097
# timer:  0.4240 sec.
# -------------
# Epoch 112/200
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0744 ||Epoch_G_Loss:0.1787
# timer:  0.4325 sec.
# -------------
# Epoch 113/200
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0880 ||Epoch_G_Loss:0.2278
# timer:  0.4284 sec.
# -------------
# Epoch 114/200
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0931 ||Epoch_G_Loss:0.1999
# timer:  0.4223 sec.
# -------------
# Epoch 115/200
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0732 ||Epoch_G_Loss:0.2312
# timer:  0.4207 sec.
# -------------
# Epoch 116/200
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0875 ||Epoch_G_Loss:0.2023
# timer:  0.4222 sec.
# -------------
# Epoch 117/200
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0736 ||Epoch_G_Loss:0.2294
# timer:  0.4260 sec.
# -------------
# Epoch 118/200
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0793 ||Epoch_G_Loss:0.2171
# timer:  0.4249 sec.
# -------------
# Epoch 119/200
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0762 ||Epoch_G_Loss:0.2278
# timer:  0.4240 sec.
# -------------
# Epoch 120/200
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0770 ||Epoch_G_Loss:0.2143
# timer:  0.4184 sec.
# -------------
# Epoch 121/200
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0762 ||Epoch_G_Loss:0.2389
# timer:  0.4240 sec.
# -------------
# Epoch 122/200
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0762 ||Epoch_G_Loss:0.2164
# timer:  0.4256 sec.
# -------------
# Epoch 123/200
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0649 ||Epoch_G_Loss:0.2484
# timer:  0.4225 sec.
# -------------
# Epoch 124/200
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0873 ||Epoch_G_Loss:0.2520
# timer:  0.4243 sec.
# -------------
# Epoch 125/200
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0856 ||Epoch_G_Loss:0.1919
# timer:  0.4234 sec.
# -------------
# Epoch 126/200
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0684 ||Epoch_G_Loss:0.2671
# timer:  0.4257 sec.
# -------------
# Epoch 127/200
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0836 ||Epoch_G_Loss:0.1995
# timer:  0.4250 sec.
# -------------
# Epoch 128/200
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0760 ||Epoch_G_Loss:0.2485
# timer:  0.4220 sec.
# -------------
# Epoch 129/200
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.2392
# timer:  0.4252 sec.
# -------------
# Epoch 130/200
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0610 ||Epoch_G_Loss:0.2656
# timer:  0.4237 sec.
# -------------
# Epoch 131/200
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0744 ||Epoch_G_Loss:0.2167
# timer:  0.4195 sec.
# -------------
# Epoch 132/200
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0683 ||Epoch_G_Loss:0.2520
# timer:  0.4217 sec.
# -------------
# Epoch 133/200
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0784 ||Epoch_G_Loss:0.2406
# timer:  0.4223 sec.
# -------------
# Epoch 134/200
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0569 ||Epoch_G_Loss:0.2587
# timer:  0.4233 sec.
# -------------
# Epoch 135/200
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0820 ||Epoch_G_Loss:0.2606
# timer:  0.4218 sec.
# -------------
# Epoch 136/200
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0711 ||Epoch_G_Loss:0.2666
# timer:  0.4188 sec.
# -------------
# Epoch 137/200
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0611 ||Epoch_G_Loss:0.2581
# timer:  0.4266 sec.
# -------------
# Epoch 138/200
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0800 ||Epoch_G_Loss:0.2524
# timer:  0.4228 sec.
# -------------
# Epoch 139/200
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0615 ||Epoch_G_Loss:0.2500
# timer:  0.4242 sec.
# -------------
# Epoch 140/200
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0720 ||Epoch_G_Loss:0.2730
# timer:  0.4226 sec.
# -------------
# Epoch 141/200
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0573 ||Epoch_G_Loss:0.2451
# timer:  0.4261 sec.
# -------------
# Epoch 142/200
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0674 ||Epoch_G_Loss:0.2827
# timer:  0.4206 sec.
# -------------
# Epoch 143/200
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0711 ||Epoch_G_Loss:0.2355
# timer:  0.4256 sec.
# -------------
# Epoch 144/200
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0621 ||Epoch_G_Loss:0.2691
# timer:  0.4276 sec.
# -------------
# Epoch 145/200
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0607 ||Epoch_G_Loss:0.2748
# timer:  0.4208 sec.
# -------------
# Epoch 146/200
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0615 ||Epoch_G_Loss:0.2919
# timer:  0.4246 sec.
# -------------
# Epoch 147/200
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0672 ||Epoch_G_Loss:0.2619
# timer:  0.4228 sec.
# -------------
# Epoch 148/200
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0720 ||Epoch_G_Loss:0.2662
# timer:  0.4223 sec.
# -------------
# Epoch 149/200
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0360 ||Epoch_G_Loss:0.3088
# timer:  0.4201 sec.
# -------------
# Epoch 150/200
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.2692
# timer:  0.4265 sec.
# -------------
# Epoch 151/200
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0544 ||Epoch_G_Loss:0.2771
# timer:  0.4249 sec.
# -------------
# Epoch 152/200
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0532 ||Epoch_G_Loss:0.2921
# timer:  0.4218 sec.
# -------------
# Epoch 153/200
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0685 ||Epoch_G_Loss:0.3050
# timer:  0.4228 sec.
# -------------
# Epoch 154/200
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0468 ||Epoch_G_Loss:0.2828
# timer:  0.4225 sec.
# -------------
# Epoch 155/200
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0607 ||Epoch_G_Loss:0.3037
# timer:  0.4257 sec.
# -------------
# Epoch 156/200
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0632 ||Epoch_G_Loss:0.2723
# timer:  0.4241 sec.
# -------------
# Epoch 157/200
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0604 ||Epoch_G_Loss:0.3225
# timer:  0.4243 sec.
# -------------
# Epoch 158/200
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0560 ||Epoch_G_Loss:0.2832
# timer:  0.4226 sec.
# -------------
# Epoch 159/200
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0532 ||Epoch_G_Loss:0.3223
# timer:  0.4177 sec.
# -------------
# Epoch 160/200
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0486 ||Epoch_G_Loss:0.3144
# timer:  0.4217 sec.
# -------------
# Epoch 161/200
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0661 ||Epoch_G_Loss:0.3103
# timer:  0.4248 sec.
# -------------
# Epoch 162/200
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0438 ||Epoch_G_Loss:0.3002
# timer:  0.4310 sec.
# -------------
# Epoch 163/200
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0517 ||Epoch_G_Loss:0.3490
# timer:  0.4277 sec.
# -------------
# Epoch 164/200
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0607 ||Epoch_G_Loss:0.2852
# timer:  0.4175 sec.
# -------------
# Epoch 165/200
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0519 ||Epoch_G_Loss:0.3513
# timer:  0.4274 sec.
# -------------
# Epoch 166/200
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0559 ||Epoch_G_Loss:0.3047
# timer:  0.4188 sec.
# -------------
# Epoch 167/200
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0428 ||Epoch_G_Loss:0.3663
# timer:  0.4238 sec.
# -------------
# Epoch 168/200
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0712 ||Epoch_G_Loss:0.3213
# timer:  0.4221 sec.
# -------------
# Epoch 169/200
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0425 ||Epoch_G_Loss:0.3158
# timer:  0.4201 sec.
# -------------
# Epoch 170/200
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0516 ||Epoch_G_Loss:0.3253
# timer:  0.4229 sec.
# -------------
# Epoch 171/200
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.3375
# timer:  0.4244 sec.
# -------------
# Epoch 172/200
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0546 ||Epoch_G_Loss:0.3597
# timer:  0.4307 sec.
# -------------
# Epoch 173/200
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0495 ||Epoch_G_Loss:0.3333
# timer:  0.4185 sec.
# -------------
# Epoch 174/200
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.3547
# timer:  0.4221 sec.
# -------------
# Epoch 175/200
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0445 ||Epoch_G_Loss:0.3227
# timer:  0.4207 sec.
# -------------
# Epoch 176/200
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0572 ||Epoch_G_Loss:0.3276
# timer:  0.4177 sec.
# -------------
# Epoch 177/200
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0562 ||Epoch_G_Loss:0.3169
# timer:  0.4258 sec.
# -------------
# Epoch 178/200
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0400 ||Epoch_G_Loss:0.3809
# timer:  0.4213 sec.
# -------------
# Epoch 179/200
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0416 ||Epoch_G_Loss:0.3738
# timer:  0.4237 sec.
# -------------
# Epoch 180/200
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0539 ||Epoch_G_Loss:0.3203
# timer:  0.4238 sec.
# -------------
# Epoch 181/200
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0506 ||Epoch_G_Loss:0.3373
# timer:  0.4263 sec.
# -------------
# Epoch 182/200
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.3855
# timer:  0.4265 sec.
# -------------
# Epoch 183/200
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0489 ||Epoch_G_Loss:0.3648
# timer:  0.4212 sec.
# -------------
# Epoch 184/200
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0401 ||Epoch_G_Loss:0.3649
# timer:  0.4274 sec.
# -------------
# Epoch 185/200
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0543 ||Epoch_G_Loss:0.3334
# timer:  0.4277 sec.
# -------------
# Epoch 186/200
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0458 ||Epoch_G_Loss:0.3932
# timer:  0.4355 sec.
# -------------
# Epoch 187/200
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0348 ||Epoch_G_Loss:0.3629
# timer:  0.4231 sec.
# -------------
# Epoch 188/200
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0718 ||Epoch_G_Loss:0.2897
# timer:  0.4257 sec.
# -------------
# Epoch 189/200
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0353 ||Epoch_G_Loss:0.3771
# timer:  0.4284 sec.
# -------------
# Epoch 190/200
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0381 ||Epoch_G_Loss:0.4011
# timer:  0.4268 sec.
# -------------
# Epoch 191/200
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0411 ||Epoch_G_Loss:0.3459
# timer:  0.4368 sec.
# -------------
# Epoch 192/200
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0375 ||Epoch_G_Loss:0.4070
# timer:  0.4222 sec.
# -------------
# Epoch 193/200
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.3786
# timer:  0.4273 sec.
# -------------
# Epoch 194/200
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0406 ||Epoch_G_Loss:0.3875
# timer:  0.4254 sec.
# -------------
# Epoch 195/200
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0386 ||Epoch_G_Loss:0.3726
# timer:  0.4220 sec.
# -------------
# Epoch 196/200
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0307 ||Epoch_G_Loss:0.4698
# timer:  0.4300 sec.
# -------------
# Epoch 197/200
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0608 ||Epoch_G_Loss:0.3054
# timer:  0.4273 sec.
# -------------
# Epoch 198/200
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0264 ||Epoch_G_Loss:0.4249
# timer:  0.4258 sec.
# -------------
# Epoch 199/200
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.4242
# timer:  0.4296 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは良い感じの画像が生成されるまで、何度も実行し直しています。

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# 以上
