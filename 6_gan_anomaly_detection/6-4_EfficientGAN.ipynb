# %% [markdown]
# # 6.4 Efficient GANの作成
#
# - 本ファイルでは、Efficient GANのネットワークを実装し、学習をします。

# %%
# !git clone https://github.com/HisakaKoji/pytorch_advanced.git
# %cd pytorch_advanced/6_gan_anomaly_detection/
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

import sklearn
print(sklearn.__version__)

# AWSのAMIでsklernのversionが0.20より低い場合はバージョンを更新します
# pip install -U scikit-learn
# MNISTの手書き数字画像をダウンロードし読み込みます
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  # data_homeは保存先を指定します
# データの取り出し
X = mnist.data
y = mnist.target
# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))
# Out:
# Cloning into 'pytorch_advanced'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 471 (delta 15), reused 0 (delta 0), pack-reused 443
# Receiving objects: 100% (471/471), 15.35 MiB | 19.35 MiB/s, done.
# Resolving deltas: 100% (250/250), done.
# /content/pytorch_advanced/6_gan_anomaly_detection
# 0.22.2.post1
# この画像データのラベルは5です

# %%
# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1
        
    # 7と8を200枚ずつ作成したらbreak
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count2+=1
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %%
# フォルダ「data」の下にフォルダ「img_78_28size」を作成する
data_dir_path = "./data/img_78_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78_28size」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1
    
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test_28size/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count2+=1 
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %% [markdown]
# # 6.4 学習目標
#
# 1.	Efficient GANを実装し、手書き数字画像で異常検知が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(z_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.Linear(1024, 7*7*128),
            nn.BatchNorm1d(7*7*128),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=128, out_channels=64,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=1,
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)

        # 転置畳み込み層に入れるためにテンソルの形を整形
        out = out.view(z.shape[0], 128, 7, 7)
        out = self.layer3(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20)
G.train()

# 入力する乱数
# バッチノーマライゼーションがあるのでミニバッチ数は2以上
input_z = torch.randn(2, 20)

# 偽画像を出力
fake_images = G(input_z)  # torch.Size([2, 1, 28, 28])
img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20):
        super(Discriminator, self).__init__()

        # 画像側の入力処理
        self.x_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.x_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        # 乱数側の入力処理
        self.z_layer1 = nn.Linear(z_dim, 512)

        # 最後の判定
        self.last1 = nn.Sequential(
            nn.Linear(3648, 1024),
            nn.LeakyReLU(0.1, inplace=True))

        self.last2 = nn.Linear(1024, 1)

    def forward(self, x, z):

        # 画像側の入力処理
        x_out = self.x_layer1(x)
        x_out = self.x_layer2(x_out)

        # 乱数側の入力処理
        z = z.view(z.shape[0], -1)
        z_out = self.z_layer1(z)

        # x_outとz_outを結合し、全結合層で判定
        x_out = x_out.view(-1, 64 * 7 * 7)
        out = torch.cat([x_out, z_out], dim=1)
        out = self.last1(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last2(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20)

# 偽画像を生成
input_z = torch.randn(2, 20)
fake_images = G(input_z)

# 偽画像をDに入力
d_out, _ = D(fake_images, input_z)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[0.4322],
#         [0.4629]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # Encoderの実装
#
# 画像をzに変換する

# %%
class Encoder(nn.Module):

    def __init__(self, z_dim=20):
        super(Encoder, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3,
                      stride=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True))

        # ここまでで画像のサイズは7×7になっている
        self.last = nn.Linear(128 * 7 * 7, z_dim)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)

        # FCに入れるためにテンソルの形を整形
        out = out.view(-1, 128 * 7 * 7)
        out = self.last(out)

        return out

# %%
# 動作確認
E = Encoder(z_dim=20)

# 入力する画像データ
x = fake_images  # fake_imagesは上のGで作成したもの

# 画像からzをEncode
z = E(x)

print(z.shape)
print(z)
# Out:
# torch.Size([2, 20])
# tensor([[-0.0669, -0.2844, -0.3601,  0.1404, -0.2922, -0.4834, -0.0025,  0.0258,
#          -0.1298, -0.2613, -0.4292, -0.2584, -0.6141, -0.1440,  0.1142,  0.2175,
#           0.0730,  0.0323, -0.7176, -0.7410],
#         [ 0.4822,  0.3682, -0.0647, -0.0773,  0.0989,  0.3012,  0.8054,  0.4399,
#           1.0848, -0.2809,  0.0619, -0.3179, -0.2963, -0.1192,  0.6562, -0.1707,
#           0.1287, -0.6156,  0.3127, -0.4819]], grad_fn=<AddmmBackward>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# # 学習させる

# %%
# モデルを学習させる関数を作成


def train_model(G, D, E, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    lr_ge = 0.0001
    lr_d = 0.0001/4
    beta1, beta2 = 0.5, 0.999
    g_optimizer = torch.optim.Adam(G.parameters(), lr_ge, [beta1, beta2])
    e_optimizer = torch.optim.Adam(E.parameters(), lr_ge, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), lr_d, [beta1, beta2])

    # 誤差関数を定義
    # BCEWithLogitsLossは入力にシグモイド（logit）をかけてから、
    # バイナリークロスエントロピーを計算
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    E.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    E.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_e_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # ミニバッチサイズの1もしくは0のラベル役のテンソルを作成
            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # 真の画像を判定　
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. Encoderの学習
            # --------------------
            # 真の画像のzを推定
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 誤差を計算
            e_loss = criterion(d_out_real.view(-1), label_fake)

            # バックプロパゲーション
            e_optimizer.zero_grad()
            e_loss.backward()
            e_optimizer.step()

            # --------------------
            # 4. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            epoch_e_loss += e_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f} ||Epoch_E_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size, epoch_e_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    print("総イテレーション回数:", iteration)

    return G, D, E

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        # 全結合層Linearの初期化
        m.bias.data.fill_(0)


# 初期化の実施
G.apply(weights_init)
E.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 1500
G_update, D_update, E_update = train_model(
    G, D, E, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/1500
# -------------
# （train）
# /pytorch/aten/src/ATen/native/TensorFactories.cpp:361: UserWarning: Deprecation warning: In a future PyTorch release torch.full will no longer return tensors of floating dtype by default. Instead, a bool fill_value will return a tensor of torch.bool dtype, and an integral fill_value will return a tensor of torch.long dtype. Set the optional `dtype` or `out` arguments to suppress this warning.
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# -------------
# Epoch 786/1500
# -------------
# （train）
# -------------
# epoch 786 || Epoch_D_Loss:0.1544 ||Epoch_G_Loss:0.0850 ||Epoch_E_Loss:0.0967
# timer:  0.2277 sec.
# -------------
# Epoch 787/1500
# -------------
# （train）
# -------------
# epoch 787 || Epoch_D_Loss:0.1459 ||Epoch_G_Loss:0.0912 ||Epoch_E_Loss:0.1020
# timer:  0.2412 sec.
# -------------
# Epoch 788/1500
# -------------
# （train）
# -------------
# epoch 788 || Epoch_D_Loss:0.1200 ||Epoch_G_Loss:0.1051 ||Epoch_E_Loss:0.1143
# timer:  0.2327 sec.
# -------------
# Epoch 789/1500
# -------------
# （train）
# -------------
# epoch 789 || Epoch_D_Loss:0.1022 ||Epoch_G_Loss:0.1140 ||Epoch_E_Loss:0.1303
# timer:  0.2388 sec.
# -------------
# Epoch 790/1500
# -------------
# （train）
# -------------
# epoch 790 || Epoch_D_Loss:0.1107 ||Epoch_G_Loss:0.1153 ||Epoch_E_Loss:0.1266
# timer:  0.2400 sec.
# -------------
# Epoch 791/1500
# -------------
# （train）
# -------------
# epoch 791 || Epoch_D_Loss:0.1235 ||Epoch_G_Loss:0.1094 ||Epoch_E_Loss:0.1112
# timer:  0.2518 sec.
# -------------
# Epoch 792/1500
# -------------
# （train）
# -------------
# epoch 792 || Epoch_D_Loss:0.1378 ||Epoch_G_Loss:0.0942 ||Epoch_E_Loss:0.1040
# timer:  0.2370 sec.
# -------------
# Epoch 793/1500
# -------------
# （train）
# -------------
# epoch 793 || Epoch_D_Loss:0.1505 ||Epoch_G_Loss:0.0905 ||Epoch_E_Loss:0.0951
# timer:  0.2383 sec.
# -------------
# Epoch 794/1500
# -------------
# （train）
# -------------
# epoch 794 || Epoch_D_Loss:0.1395 ||Epoch_G_Loss:0.0967 ||Epoch_E_Loss:0.1072
# timer:  0.2363 sec.
# -------------
# Epoch 795/1500
# -------------
# （train）
# -------------
# epoch 795 || Epoch_D_Loss:0.1166 ||Epoch_G_Loss:0.1140 ||Epoch_E_Loss:0.1156
# timer:  0.2415 sec.
# -------------
# Epoch 796/1500
# -------------
# （train）
# -------------
# epoch 796 || Epoch_D_Loss:0.1044 ||Epoch_G_Loss:0.1284 ||Epoch_E_Loss:0.1284
# timer:  0.2335 sec.
# -------------
# Epoch 797/1500
# -------------
# （train）
# -------------
# epoch 797 || Epoch_D_Loss:0.1120 ||Epoch_G_Loss:0.1175 ||Epoch_E_Loss:0.1288
# timer:  0.2500 sec.
# -------------
# Epoch 798/1500
# -------------
# （train）
# -------------
# epoch 798 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.1043 ||Epoch_E_Loss:0.1302
# timer:  0.2420 sec.
# -------------
# Epoch 799/1500
# -------------
# （train）
# -------------
# epoch 799 || Epoch_D_Loss:0.1327 ||Epoch_G_Loss:0.0958 ||Epoch_E_Loss:0.1143
# timer:  0.2411 sec.
# -------------
# Epoch 800/1500
# -------------
# （train）
# -------------
# epoch 800 || Epoch_D_Loss:0.1482 ||Epoch_G_Loss:0.0987 ||Epoch_E_Loss:0.1014
# timer:  0.2490 sec.
# -------------
# Epoch 801/1500
# -------------
# （train）
# -------------
# epoch 801 || Epoch_D_Loss:0.1265 ||Epoch_G_Loss:0.1064 ||Epoch_E_Loss:0.1140
# timer:  0.2331 sec.
# -------------
# Epoch 802/1500
# -------------
# （train）
# -------------
# epoch 802 || Epoch_D_Loss:0.1165 ||Epoch_G_Loss:0.1143 ||Epoch_E_Loss:0.1273
# timer:  0.2322 sec.
# -------------
# Epoch 803/1500
# -------------
# （train）
# -------------
# epoch 803 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1191 ||Epoch_E_Loss:0.1285
# timer:  0.2296 sec.
# -------------
# Epoch 804/1500
# -------------
# （train）
# -------------
# epoch 804 || Epoch_D_Loss:0.1327 ||Epoch_G_Loss:0.1040 ||Epoch_E_Loss:0.1179
# timer:  0.2598 sec.
# -------------
# Epoch 805/1500
# -------------
# （train）
# -------------
# epoch 805 || Epoch_D_Loss:0.1421 ||Epoch_G_Loss:0.1022 ||Epoch_E_Loss:0.1026
# timer:  0.2243 sec.
# -------------
# Epoch 806/1500
# -------------
# （train）
# -------------
# epoch 806 || Epoch_D_Loss:0.1378 ||Epoch_G_Loss:0.1013 ||Epoch_E_Loss:0.1133
# timer:  0.2310 sec.
# -------------
# Epoch 807/1500
# -------------
# （train）
# -------------
# epoch 807 || Epoch_D_Loss:0.1279 ||Epoch_G_Loss:0.1040 ||Epoch_E_Loss:0.1174
# timer:  0.2303 sec.
# -------------
# Epoch 808/1500
# -------------
# （train）
# -------------
# epoch 808 || Epoch_D_Loss:0.1301 ||Epoch_G_Loss:0.1110 ||Epoch_E_Loss:0.1153
# timer:  0.2370 sec.
# -------------
# Epoch 809/1500
# -------------
# （train）
# -------------
# epoch 809 || Epoch_D_Loss:0.1268 ||Epoch_G_Loss:0.0999 ||Epoch_E_Loss:0.1238
# timer:  0.2413 sec.
# -------------
# Epoch 810/1500
# -------------
# （train）
# -------------
# epoch 810 || Epoch_D_Loss:0.1193 ||Epoch_G_Loss:0.1237 ||Epoch_E_Loss:0.1252
# timer:  0.2360 sec.
# -------------
# Epoch 811/1500
# -------------
# （train）
# -------------
# epoch 811 || Epoch_D_Loss:0.1087 ||Epoch_G_Loss:0.1131 ||Epoch_E_Loss:0.1335
# timer:  0.2343 sec.
# -------------
# Epoch 812/1500
# -------------
# （train）
# -------------
# epoch 812 || Epoch_D_Loss:0.1296 ||Epoch_G_Loss:0.1040 ||Epoch_E_Loss:0.1157
# timer:  0.2323 sec.
# -------------
# Epoch 813/1500
# -------------
# （train）
# -------------
# epoch 813 || Epoch_D_Loss:0.1407 ||Epoch_G_Loss:0.0934 ||Epoch_E_Loss:0.1183
# timer:  0.2432 sec.
# -------------
# Epoch 814/1500
# -------------
# （train）
# -------------
# epoch 814 || Epoch_D_Loss:0.1371 ||Epoch_G_Loss:0.0967 ||Epoch_E_Loss:0.1256
# timer:  0.2330 sec.
# -------------
# Epoch 815/1500
# -------------
# （train）
# -------------
# epoch 815 || Epoch_D_Loss:0.1390 ||Epoch_G_Loss:0.1021 ||Epoch_E_Loss:0.1154
# timer:  0.2388 sec.
# -------------
# Epoch 816/1500
# -------------
# （train）
# -------------
# epoch 816 || Epoch_D_Loss:0.1340 ||Epoch_G_Loss:0.0934 ||Epoch_E_Loss:0.1316
# timer:  0.2282 sec.
# -------------
# Epoch 817/1500
# -------------
# （train）
# -------------
# epoch 817 || Epoch_D_Loss:0.1289 ||Epoch_G_Loss:0.1117 ||Epoch_E_Loss:0.1204
# timer:  0.2382 sec.
# -------------
# Epoch 818/1500
# -------------
# （train）
# -------------
# epoch 818 || Epoch_D_Loss:0.1308 ||Epoch_G_Loss:0.0998 ||Epoch_E_Loss:0.1249
# timer:  0.2303 sec.
# -------------
# Epoch 819/1500
# -------------
# （train）
# -------------
# epoch 819 || Epoch_D_Loss:0.1374 ||Epoch_G_Loss:0.1039 ||Epoch_E_Loss:0.1125
# timer:  0.2259 sec.
# -------------
# Epoch 820/1500
# -------------
# （train）
# -------------
# epoch 820 || Epoch_D_Loss:0.1380 ||Epoch_G_Loss:0.0907 ||Epoch_E_Loss:0.1133
# timer:  0.2327 sec.
# -------------
# Epoch 821/1500
# -------------
# （train）
# -------------
# epoch 821 || Epoch_D_Loss:0.1409 ||Epoch_G_Loss:0.0952 ||Epoch_E_Loss:0.1117
# timer:  0.2456 sec.
# -------------
# Epoch 822/1500
# -------------
# （train）
# -------------
# epoch 822 || Epoch_D_Loss:0.1371 ||Epoch_G_Loss:0.0901 ||Epoch_E_Loss:0.1161
# timer:  0.2245 sec.
# -------------
# Epoch 823/1500
# -------------
# （train）
# -------------
# epoch 823 || Epoch_D_Loss:0.1361 ||Epoch_G_Loss:0.1053 ||Epoch_E_Loss:0.1181
# timer:  0.2263 sec.
# -------------
# Epoch 824/1500
# -------------
# （train）
# -------------
# epoch 824 || Epoch_D_Loss:0.1192 ||Epoch_G_Loss:0.1169 ||Epoch_E_Loss:0.1204
# timer:  0.2259 sec.
# -------------
# Epoch 825/1500
# -------------
# （train）
# -------------
# epoch 825 || Epoch_D_Loss:0.1175 ||Epoch_G_Loss:0.1115 ||Epoch_E_Loss:0.1281
# timer:  0.2264 sec.
# -------------
# Epoch 826/1500
# -------------
# （train）
# -------------
# epoch 826 || Epoch_D_Loss:0.1259 ||Epoch_G_Loss:0.1228 ||Epoch_E_Loss:0.1176
# timer:  0.2406 sec.
# -------------
# Epoch 827/1500
# -------------
# （train）
# -------------
# epoch 827 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1151 ||Epoch_E_Loss:0.1278
# timer:  0.2329 sec.
# -------------
# Epoch 828/1500
# -------------
# （train）
# -------------
# epoch 828 || Epoch_D_Loss:0.1274 ||Epoch_G_Loss:0.1188 ||Epoch_E_Loss:0.1210
# timer:  0.2418 sec.
# -------------
# Epoch 829/1500
# -------------
# （train）
# -------------
# epoch 829 || Epoch_D_Loss:0.1234 ||Epoch_G_Loss:0.1202 ||Epoch_E_Loss:0.1174
# timer:  0.2248 sec.
# -------------
# Epoch 830/1500
# -------------
# （train）
# -------------
# epoch 830 || Epoch_D_Loss:0.1263 ||Epoch_G_Loss:0.1064 ||Epoch_E_Loss:0.1272
# timer:  0.2423 sec.
# -------------
# Epoch 831/1500
# -------------
# （train）
# -------------
# epoch 831 || Epoch_D_Loss:0.1309 ||Epoch_G_Loss:0.1053 ||Epoch_E_Loss:0.1128
# timer:  0.2314 sec.
# -------------
# Epoch 832/1500
# -------------
# （train）
# -------------
# epoch 832 || Epoch_D_Loss:0.1353 ||Epoch_G_Loss:0.0929 ||Epoch_E_Loss:0.1215
# timer:  0.2303 sec.
# -------------
# Epoch 833/1500
# -------------
# （train）
# -------------
# epoch 833 || Epoch_D_Loss:0.1342 ||Epoch_G_Loss:0.1137 ||Epoch_E_Loss:0.1214
# timer:  0.2277 sec.
# -------------
# Epoch 834/1500
# -------------
# （train）
# -------------
# epoch 834 || Epoch_D_Loss:0.1232 ||Epoch_G_Loss:0.1054 ||Epoch_E_Loss:0.1312
# timer:  0.2387 sec.
# -------------
# Epoch 835/1500
# -------------
# （train）
# -------------
# epoch 835 || Epoch_D_Loss:0.1353 ||Epoch_G_Loss:0.1119 ||Epoch_E_Loss:0.1180
# timer:  0.2371 sec.
# -------------
# Epoch 836/1500
# -------------
# （train）
# -------------
# epoch 836 || Epoch_D_Loss:0.1221 ||Epoch_G_Loss:0.1144 ||Epoch_E_Loss:0.1310
# timer:  0.2377 sec.
# -------------
# Epoch 837/1500
# -------------
# （train）
# -------------
# epoch 837 || Epoch_D_Loss:0.1213 ||Epoch_G_Loss:0.1075 ||Epoch_E_Loss:0.1291
# timer:  0.2329 sec.
# -------------
# Epoch 838/1500
# -------------
# （train）
# -------------
# epoch 838 || Epoch_D_Loss:0.1432 ||Epoch_G_Loss:0.0997 ||Epoch_E_Loss:0.1112
# timer:  0.2327 sec.
# -------------
# Epoch 839/1500
# -------------
# （train）
# -------------
# epoch 839 || Epoch_D_Loss:0.1440 ||Epoch_G_Loss:0.0962 ||Epoch_E_Loss:0.1199
# timer:  0.2413 sec.
# -------------
# Epoch 840/1500
# -------------
# （train）
# -------------
# epoch 840 || Epoch_D_Loss:0.1320 ||Epoch_G_Loss:0.0990 ||Epoch_E_Loss:0.1178
# timer:  0.2324 sec.
# -------------
# Epoch 841/1500
# -------------
# （train）
# -------------
# epoch 841 || Epoch_D_Loss:0.1341 ||Epoch_G_Loss:0.1059 ||Epoch_E_Loss:0.1235
# timer:  0.2323 sec.
# -------------
# Epoch 842/1500
# -------------
# （train）
# -------------
# epoch 842 || Epoch_D_Loss:0.1238 ||Epoch_G_Loss:0.1119 ||Epoch_E_Loss:0.1223
# timer:  0.2250 sec.
# -------------
# Epoch 843/1500
# -------------
# （train）
# -------------
# epoch 843 || Epoch_D_Loss:0.1368 ||Epoch_G_Loss:0.1110 ||Epoch_E_Loss:0.1151
# timer:  0.2417 sec.
# -------------
# Epoch 844/1500
# -------------
# （train）
# -------------
# epoch 844 || Epoch_D_Loss:0.1446 ||Epoch_G_Loss:0.1051 ||Epoch_E_Loss:0.1119
# timer:  0.2385 sec.
# -------------
# Epoch 845/1500
# -------------
# （train）
# -------------
# epoch 845 || Epoch_D_Loss:0.1399 ||Epoch_G_Loss:0.0935 ||Epoch_E_Loss:0.1137
# timer:  0.2328 sec.
# -------------
# Epoch 846/1500
# -------------
# （train）
# -------------
# epoch 846 || Epoch_D_Loss:0.1291 ||Epoch_G_Loss:0.1015 ||Epoch_E_Loss:0.1205
# timer:  0.2322 sec.
# -------------
# Epoch 847/1500
# -------------
# （train）
# -------------
# epoch 847 || Epoch_D_Loss:0.1182 ||Epoch_G_Loss:0.1202 ||Epoch_E_Loss:0.1259
# timer:  0.2366 sec.
# -------------
# Epoch 848/1500
# -------------
# （train）
# -------------
# epoch 848 || Epoch_D_Loss:0.1164 ||Epoch_G_Loss:0.1108 ||Epoch_E_Loss:0.1282
# timer:  0.2491 sec.
# -------------
# Epoch 849/1500
# -------------
# （train）
# -------------
# epoch 849 || Epoch_D_Loss:0.1468 ||Epoch_G_Loss:0.0900 ||Epoch_E_Loss:0.1083
# timer:  0.2253 sec.
# -------------
# Epoch 850/1500
# -------------
# （train）
# -------------
# epoch 850 || Epoch_D_Loss:0.1682 ||Epoch_G_Loss:0.0878 ||Epoch_E_Loss:0.0977
# timer:  0.2281 sec.
# -------------
# Epoch 851/1500
# -------------
# （train）
# -------------
# epoch 851 || Epoch_D_Loss:0.1508 ||Epoch_G_Loss:0.0998 ||Epoch_E_Loss:0.0999
# timer:  0.2369 sec.
# -------------
# Epoch 852/1500
# -------------
# （train）
# -------------
# epoch 852 || Epoch_D_Loss:0.1335 ||Epoch_G_Loss:0.1096 ||Epoch_E_Loss:0.1112
# timer:  0.2344 sec.
# -------------
# Epoch 853/1500
# -------------
# （train）
# -------------
# epoch 853 || Epoch_D_Loss:0.1287 ||Epoch_G_Loss:0.1151 ||Epoch_E_Loss:0.1152
# timer:  0.2298 sec.
# -------------
# Epoch 854/1500
# -------------
# （train）
# -------------
# epoch 854 || Epoch_D_Loss:0.1275 ||Epoch_G_Loss:0.1053 ||Epoch_E_Loss:0.1213
# timer:  0.2405 sec.
# -------------
# Epoch 855/1500
# -------------
# （train）
# -------------
# epoch 855 || Epoch_D_Loss:0.1139 ||Epoch_G_Loss:0.1150 ||Epoch_E_Loss:0.1238
# timer:  0.2358 sec.
# -------------
# Epoch 856/1500
# -------------
# （train）
# -------------
# epoch 856 || Epoch_D_Loss:0.1164 ||Epoch_G_Loss:0.1070 ||Epoch_E_Loss:0.1223
# timer:  0.2459 sec.
# -------------
# Epoch 857/1500
# -------------
# （train）
# -------------
# epoch 857 || Epoch_D_Loss:0.1405 ||Epoch_G_Loss:0.0970 ||Epoch_E_Loss:0.1067
# timer:  0.2322 sec.
# -------------
# Epoch 858/1500
# -------------
# （train）
# -------------
# epoch 858 || Epoch_D_Loss:0.1642 ||Epoch_G_Loss:0.0900 ||Epoch_E_Loss:0.0860
# timer:  0.2216 sec.
# -------------
# Epoch 859/1500
# -------------
# （train）
# -------------
# epoch 859 || Epoch_D_Loss:0.1538 ||Epoch_G_Loss:0.0830 ||Epoch_E_Loss:0.0986
# timer:  0.2239 sec.
# -------------
# Epoch 860/1500
# -------------
# （train）
# -------------
# epoch 860 || Epoch_D_Loss:0.1243 ||Epoch_G_Loss:0.1059 ||Epoch_E_Loss:0.1121
# timer:  0.2316 sec.
# -------------
# Epoch 861/1500
# -------------
# （train）
# -------------
# epoch 861 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.1176 ||Epoch_E_Loss:0.1224
# timer:  0.2422 sec.
# -------------
# Epoch 862/1500
# -------------
# （train）
# -------------
# epoch 862 || Epoch_D_Loss:0.1083 ||Epoch_G_Loss:0.1191 ||Epoch_E_Loss:0.1255
# timer:  0.2364 sec.
# -------------
# Epoch 863/1500
# -------------
# （train）
# -------------
# epoch 863 || Epoch_D_Loss:0.1120 ||Epoch_G_Loss:0.1059 ||Epoch_E_Loss:0.1209
# timer:  0.2265 sec.
# -------------
# Epoch 864/1500
# -------------
# （train）
# -------------
# epoch 864 || Epoch_D_Loss:0.1248 ||Epoch_G_Loss:0.1107 ||Epoch_E_Loss:0.1069
# timer:  0.2336 sec.
# -------------
# Epoch 865/1500
# -------------
# （train）
# -------------
# epoch 865 || Epoch_D_Loss:0.1179 ||Epoch_G_Loss:0.1058 ||Epoch_E_Loss:0.1206
# timer:  0.2447 sec.
# -------------
# Epoch 866/1500
# -------------
# （train）
# -------------
# epoch 866 || Epoch_D_Loss:0.1221 ||Epoch_G_Loss:0.1127 ||Epoch_E_Loss:0.1120
# timer:  0.2264 sec.
# -------------
# Epoch 867/1500
# -------------
# （train）
# -------------
# epoch 867 || Epoch_D_Loss:0.1261 ||Epoch_G_Loss:0.0970 ||Epoch_E_Loss:0.1150
# timer:  0.2253 sec.
# -------------
# Epoch 868/1500
# -------------
# （train）
# -------------
# epoch 868 || Epoch_D_Loss:0.1338 ||Epoch_G_Loss:0.1009 ||Epoch_E_Loss:0.1059
# timer:  0.2254 sec.
# -------------
# Epoch 869/1500
# -------------
# （train）
# -------------
# epoch 869 || Epoch_D_Loss:0.1246 ||Epoch_G_Loss:0.1051 ||Epoch_E_Loss:0.1125
# timer:  0.2309 sec.
# -------------
# Epoch 870/1500
# -------------
# （train）
# -------------
# epoch 870 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1119 ||Epoch_E_Loss:0.1178
# timer:  0.2351 sec.
# -------------
# Epoch 871/1500
# -------------
# （train）
# -------------
# epoch 871 || Epoch_D_Loss:0.1092 ||Epoch_G_Loss:0.1198 ||Epoch_E_Loss:0.1218
# timer:  0.2289 sec.
# -------------
# Epoch 872/1500
# -------------
# （train）
# -------------
# epoch 872 || Epoch_D_Loss:0.1152 ||Epoch_G_Loss:0.1218 ||Epoch_E_Loss:0.1158
# timer:  0.2308 sec.
# -------------
# Epoch 873/1500
# -------------
# （train）
# -------------
# epoch 873 || Epoch_D_Loss:0.1209 ||Epoch_G_Loss:0.1091 ||Epoch_E_Loss:0.1202
# timer:  0.2322 sec.
# -------------
# Epoch 874/1500
# -------------
# （train）
# -------------
# epoch 874 || Epoch_D_Loss:0.1192 ||Epoch_G_Loss:0.1083 ||Epoch_E_Loss:0.1155
# timer:  0.2343 sec.
# -------------
# Epoch 875/1500
# -------------
# （train）
# -------------
# epoch 875 || Epoch_D_Loss:0.1146 ||Epoch_G_Loss:0.1071 ||Epoch_E_Loss:0.1159
# timer:  0.2297 sec.
# -------------
# Epoch 876/1500
# -------------
# （train）
# -------------
# epoch 876 || Epoch_D_Loss:0.1132 ||Epoch_G_Loss:0.1131 ||Epoch_E_Loss:0.1155
# timer:  0.2329 sec.
# -------------
# Epoch 877/1500
# -------------
# （train）
# -------------
# epoch 877 || Epoch_D_Loss:0.1209 ||Epoch_G_Loss:0.1062 ||Epoch_E_Loss:0.1198
# timer:  0.2264 sec.
# -------------
# Epoch 878/1500
# -------------
# （train）
# -------------
# epoch 878 || Epoch_D_Loss:0.1179 ||Epoch_G_Loss:0.1038 ||Epoch_E_Loss:0.1139
# timer:  0.2460 sec.
# -------------
# Epoch 879/1500
# -------------
# （train）
# -------------
# epoch 879 || Epoch_D_Loss:0.1214 ||Epoch_G_Loss:0.1093 ||Epoch_E_Loss:0.1100
# timer:  0.2274 sec.
# -------------
# Epoch 880/1500
# -------------
# （train）
# -------------
# epoch 880 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.1023 ||Epoch_E_Loss:0.1190
# timer:  0.2346 sec.
# -------------
# Epoch 881/1500
# -------------
# （train）
# -------------
# epoch 881 || Epoch_D_Loss:0.1129 ||Epoch_G_Loss:0.1196 ||Epoch_E_Loss:0.1158
# timer:  0.2487 sec.
# -------------
# Epoch 882/1500
# -------------
# （train）
# -------------
# epoch 882 || Epoch_D_Loss:0.1098 ||Epoch_G_Loss:0.1123 ||Epoch_E_Loss:0.1252
# timer:  0.2680 sec.
# -------------
# Epoch 883/1500
# -------------
# （train）
# -------------
# epoch 883 || Epoch_D_Loss:0.1118 ||Epoch_G_Loss:0.1101 ||Epoch_E_Loss:0.1251
# timer:  0.2361 sec.
# -------------
# Epoch 884/1500
# -------------
# （train）
# -------------
# epoch 884 || Epoch_D_Loss:0.1120 ||Epoch_G_Loss:0.1071 ||Epoch_E_Loss:0.1264
# timer:  0.2357 sec.
# -------------
# Epoch 885/1500
# -------------
# （train）
# -------------
# epoch 885 || Epoch_D_Loss:0.1166 ||Epoch_G_Loss:0.1127 ||Epoch_E_Loss:0.1187
# timer:  0.2333 sec.
# -------------
# Epoch 886/1500
# -------------
# （train）
# -------------
# epoch 886 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.1103 ||Epoch_E_Loss:0.1245
# timer:  0.2392 sec.
# -------------
# Epoch 887/1500
# -------------
# （train）
# -------------
# epoch 887 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.1301 ||Epoch_E_Loss:0.1210
# timer:  0.2423 sec.
# -------------
# Epoch 888/1500
# -------------
# （train）
# -------------
# epoch 888 || Epoch_D_Loss:0.1102 ||Epoch_G_Loss:0.1029 ||Epoch_E_Loss:0.1312
# timer:  0.2466 sec.
# -------------
# Epoch 889/1500
# -------------
# （train）
# -------------
# epoch 889 || Epoch_D_Loss:0.1373 ||Epoch_G_Loss:0.1071 ||Epoch_E_Loss:0.1020
# timer:  0.2450 sec.
# -------------
# Epoch 890/1500
# -------------
# （train）
# -------------
# epoch 890 || Epoch_D_Loss:0.1317 ||Epoch_G_Loss:0.0956 ||Epoch_E_Loss:0.1089
# timer:  0.2484 sec.
# -------------
# Epoch 891/1500
# -------------
# （train）
# -------------
# epoch 891 || Epoch_D_Loss:0.1249 ||Epoch_G_Loss:0.1099 ||Epoch_E_Loss:0.1147
# timer:  0.2412 sec.
# -------------
# Epoch 892/1500
# -------------
# （train）
# -------------
# epoch 892 || Epoch_D_Loss:0.1089 ||Epoch_G_Loss:0.1190 ||Epoch_E_Loss:0.1236
# timer:  0.2413 sec.
# -------------
# Epoch 893/1500
# -------------
# （train）
# -------------
# epoch 893 || Epoch_D_Loss:0.0999 ||Epoch_G_Loss:0.1236 ||Epoch_E_Loss:0.1334
# timer:  0.2423 sec.
# -------------
# Epoch 894/1500
# -------------
# （train）
# -------------
# epoch 894 || Epoch_D_Loss:0.0986 ||Epoch_G_Loss:0.1172 ||Epoch_E_Loss:0.1371
# timer:  0.2373 sec.
# -------------
# Epoch 895/1500
# -------------
# （train）
# -------------
# epoch 895 || Epoch_D_Loss:0.1267 ||Epoch_G_Loss:0.1223 ||Epoch_E_Loss:0.1180
# timer:  0.2480 sec.
# -------------
# Epoch 896/1500
# -------------
# （train）
# -------------
# epoch 896 || Epoch_D_Loss:0.1245 ||Epoch_G_Loss:0.1080 ||Epoch_E_Loss:0.1105
# timer:  0.2278 sec.
# -------------
# Epoch 897/1500
# -------------
# （train）
# -------------
# epoch 897 || Epoch_D_Loss:0.1377 ||Epoch_G_Loss:0.0965 ||Epoch_E_Loss:0.1099
# timer:  0.2329 sec.
# -------------
# Epoch 898/1500
# -------------
# （train）
# -------------
# epoch 898 || Epoch_D_Loss:0.1264 ||Epoch_G_Loss:0.1054 ||Epoch_E_Loss:0.1148
# timer:  0.2324 sec.
# -------------
# Epoch 899/1500
# -------------
# （train）
# -------------
# epoch 899 || Epoch_D_Loss:0.1152 ||Epoch_G_Loss:0.1044 ||Epoch_E_Loss:0.1259
# timer:  0.2654 sec.
# -------------
# Epoch 900/1500
# -------------
# （train）
# -------------
# epoch 900 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1187 ||Epoch_E_Loss:0.1254
# timer:  0.2351 sec.
# -------------
# Epoch 901/1500
# -------------
# （train）
# -------------
# epoch 901 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1202 ||Epoch_E_Loss:0.1295
# timer:  0.2274 sec.
# -------------
# Epoch 902/1500
# -------------
# （train）
# -------------
# epoch 902 || Epoch_D_Loss:0.1136 ||Epoch_G_Loss:0.1102 ||Epoch_E_Loss:0.1279
# timer:  0.2360 sec.
# -------------
# Epoch 903/1500
# -------------
# （train）
# -------------
# epoch 903 || Epoch_D_Loss:0.1253 ||Epoch_G_Loss:0.1003 ||Epoch_E_Loss:0.1177
# timer:  0.2377 sec.
# -------------
# Epoch 904/1500
# -------------
# （train）
# -------------
# epoch 904 || Epoch_D_Loss:0.1224 ||Epoch_G_Loss:0.1093 ||Epoch_E_Loss:0.1141
# timer:  0.2343 sec.
# -------------
# Epoch 905/1500
# -------------
# （train）
# -------------
# epoch 905 || Epoch_D_Loss:0.1286 ||Epoch_G_Loss:0.1007 ||Epoch_E_Loss:0.1233
# timer:  0.2360 sec.
# -------------
# Epoch 906/1500
# -------------
# （train）
# -------------
# epoch 906 || Epoch_D_Loss:0.1329 ||Epoch_G_Loss:0.1075 ||Epoch_E_Loss:0.1135
# timer:  0.2335 sec.
# -------------
# Epoch 907/1500
# -------------
# （train）
# -------------
# epoch 907 || Epoch_D_Loss:0.1213 ||Epoch_G_Loss:0.1153 ||Epoch_E_Loss:0.1170
# timer:  0.2329 sec.
# -------------
# Epoch 908/1500
# -------------
# （train）
# -------------
# epoch 908 || Epoch_D_Loss:0.1212 ||Epoch_G_Loss:0.1119 ||Epoch_E_Loss:0.1214
# timer:  0.2372 sec.
# -------------
# Epoch 909/1500
# -------------
# （train）
# -------------
# epoch 909 || Epoch_D_Loss:0.1234 ||Epoch_G_Loss:0.1116 ||Epoch_E_Loss:0.1165
# timer:  0.2300 sec.
# -------------
# Epoch 910/1500
# -------------
# （train）
# -------------
# epoch 910 || Epoch_D_Loss:0.1266 ||Epoch_G_Loss:0.1011 ||Epoch_E_Loss:0.1148
# timer:  0.2338 sec.
# -------------
# Epoch 911/1500
# -------------
# （train）
# -------------
# epoch 911 || Epoch_D_Loss:0.1203 ||Epoch_G_Loss:0.1183 ||Epoch_E_Loss:0.1204
# timer:  0.2479 sec.
# -------------
# Epoch 912/1500
# -------------
# （train）
# -------------
# epoch 912 || Epoch_D_Loss:0.1093 ||Epoch_G_Loss:0.1224 ||Epoch_E_Loss:0.1312
# timer:  0.2391 sec.
# -------------
# Epoch 913/1500
# -------------
# （train）
# -------------
# epoch 913 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.1255 ||Epoch_E_Loss:0.1220
# timer:  0.2302 sec.
# -------------
# Epoch 914/1500
# -------------
# （train）
# -------------
# epoch 914 || Epoch_D_Loss:0.1170 ||Epoch_G_Loss:0.1037 ||Epoch_E_Loss:0.1383
# timer:  0.2310 sec.
# -------------
# Epoch 915/1500
# -------------
# （train）
# -------------
# epoch 915 || Epoch_D_Loss:0.1291 ||Epoch_G_Loss:0.1087 ||Epoch_E_Loss:0.1204
# timer:  0.2290 sec.
# -------------
# Epoch 916/1500
# -------------
# （train）
# -------------
# epoch 916 || Epoch_D_Loss:0.1316 ||Epoch_G_Loss:0.1047 ||Epoch_E_Loss:0.1101
# timer:  0.2429 sec.
# -------------
# Epoch 917/1500
# -------------
# （train）
# -------------
# epoch 917 || Epoch_D_Loss:0.1325 ||Epoch_G_Loss:0.0953 ||Epoch_E_Loss:0.1180
# timer:  0.2506 sec.
# -------------
# Epoch 918/1500
# -------------
# （train）
# -------------
# epoch 918 || Epoch_D_Loss:0.1255 ||Epoch_G_Loss:0.1113 ||Epoch_E_Loss:0.1165
# timer:  0.2247 sec.
# -------------
# Epoch 919/1500
# -------------
# （train）
# -------------
# epoch 919 || Epoch_D_Loss:0.1096 ||Epoch_G_Loss:0.1146 ||Epoch_E_Loss:0.1251
# timer:  0.2271 sec.
# -------------
# Epoch 920/1500
# -------------
# （train）
# -------------
# epoch 920 || Epoch_D_Loss:0.1118 ||Epoch_G_Loss:0.1108 ||Epoch_E_Loss:0.1309
# timer:  0.2383 sec.
# -------------
# Epoch 921/1500
# -------------
# （train）
# -------------
# epoch 921 || Epoch_D_Loss:0.1219 ||Epoch_G_Loss:0.1194 ||Epoch_E_Loss:0.1238
# timer:  0.2356 sec.
# -------------
# Epoch 922/1500
# -------------
# （train）
# -------------
# epoch 922 || Epoch_D_Loss:0.1185 ||Epoch_G_Loss:0.1083 ||Epoch_E_Loss:0.1189
# timer:  0.2402 sec.
# -------------
# Epoch 923/1500
# -------------
# （train）
# -------------
# epoch 923 || Epoch_D_Loss:0.1179 ||Epoch_G_Loss:0.1132 ||Epoch_E_Loss:0.1255
# timer:  0.2343 sec.
# -------------
# Epoch 924/1500
# -------------
# （train）
# -------------
# epoch 924 || Epoch_D_Loss:0.1162 ||Epoch_G_Loss:0.1079 ||Epoch_E_Loss:0.1231
# timer:  0.2294 sec.
# -------------
# Epoch 925/1500
# -------------
# （train）
# -------------
# epoch 925 || Epoch_D_Loss:0.1285 ||Epoch_G_Loss:0.1072 ||Epoch_E_Loss:0.1160
# timer:  0.2443 sec.
# -------------
# Epoch 926/1500
# -------------
# （train）
# -------------
# epoch 926 || Epoch_D_Loss:0.1317 ||Epoch_G_Loss:0.1151 ||Epoch_E_Loss:0.1056
# timer:  0.2353 sec.
# -------------
# Epoch 927/1500
# -------------
# （train）
# -------------
# epoch 927 || Epoch_D_Loss:0.1327 ||Epoch_G_Loss:0.0964 ||Epoch_E_Loss:0.1190
# timer:  0.2329 sec.
# -------------
# Epoch 928/1500
# -------------
# （train）
# -------------
# epoch 928 || Epoch_D_Loss:0.1200 ||Epoch_G_Loss:0.1034 ||Epoch_E_Loss:0.1269
# timer:  0.2452 sec.
# -------------
# Epoch 929/1500
# -------------
# （train）
# -------------
# epoch 929 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1329 ||Epoch_E_Loss:0.1263
# timer:  0.2356 sec.
# -------------
# Epoch 930/1500
# -------------
# （train）
# -------------
# epoch 930 || Epoch_D_Loss:0.1067 ||Epoch_G_Loss:0.1124 ||Epoch_E_Loss:0.1378
# timer:  0.2363 sec.
# -------------
# Epoch 931/1500
# -------------
# （train）
# -------------
# epoch 931 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.1229 ||Epoch_E_Loss:0.1263
# timer:  0.2296 sec.
# -------------
# Epoch 932/1500
# -------------
# （train）
# -------------
# epoch 932 || Epoch_D_Loss:0.1151 ||Epoch_G_Loss:0.1182 ||Epoch_E_Loss:0.1251
# timer:  0.2335 sec.
# -------------
# Epoch 933/1500
# -------------
# （train）
# -------------
# epoch 933 || Epoch_D_Loss:0.1247 ||Epoch_G_Loss:0.1099 ||Epoch_E_Loss:0.1237
# timer:  0.2353 sec.
# -------------
# Epoch 934/1500
# -------------
# （train）
# -------------
# epoch 934 || Epoch_D_Loss:0.1261 ||Epoch_G_Loss:0.1093 ||Epoch_E_Loss:0.1144
# timer:  0.2491 sec.
# -------------
# Epoch 935/1500
# -------------
# （train）
# -------------
# epoch 935 || Epoch_D_Loss:0.1277 ||Epoch_G_Loss:0.1158 ||Epoch_E_Loss:0.1163
# timer:  0.2321 sec.
# -------------
# Epoch 936/1500
# -------------
# （train）
# -------------
# epoch 936 || Epoch_D_Loss:0.1302 ||Epoch_G_Loss:0.0986 ||Epoch_E_Loss:0.1281
# timer:  0.2354 sec.
# -------------
# Epoch 937/1500
# -------------
# （train）
# -------------
# epoch 937 || Epoch_D_Loss:0.1321 ||Epoch_G_Loss:0.1040 ||Epoch_E_Loss:0.1178
# timer:  0.2390 sec.
# -------------
# Epoch 938/1500
# -------------
# （train）
# -------------
# epoch 938 || Epoch_D_Loss:0.1258 ||Epoch_G_Loss:0.1076 ||Epoch_E_Loss:0.1209
# timer:  0.2376 sec.
# -------------
# Epoch 939/1500
# -------------
# （train）
# -------------
# epoch 939 || Epoch_D_Loss:0.1170 ||Epoch_G_Loss:0.1216 ||Epoch_E_Loss:0.1318
# timer:  0.2407 sec.
# -------------
# Epoch 940/1500
# -------------
# （train）
# -------------
# epoch 940 || Epoch_D_Loss:0.1150 ||Epoch_G_Loss:0.1104 ||Epoch_E_Loss:0.1368
# timer:  0.2313 sec.
# -------------
# Epoch 941/1500
# -------------
# （train）
# -------------
# epoch 941 || Epoch_D_Loss:0.1391 ||Epoch_G_Loss:0.0946 ||Epoch_E_Loss:0.1176
# timer:  0.2369 sec.
# -------------
# Epoch 942/1500
# -------------
# （train）
# -------------
# epoch 942 || Epoch_D_Loss:0.1424 ||Epoch_G_Loss:0.0955 ||Epoch_E_Loss:0.1152
# timer:  0.2399 sec.
# -------------
# Epoch 943/1500
# -------------
# （train）
# -------------
# epoch 943 || Epoch_D_Loss:0.1149 ||Epoch_G_Loss:0.1121 ||Epoch_E_Loss:0.1347
# timer:  0.2348 sec.
# -------------
# Epoch 944/1500
# -------------
# （train）
# -------------
# epoch 944 || Epoch_D_Loss:0.1207 ||Epoch_G_Loss:0.1000 ||Epoch_E_Loss:0.1357
# timer:  0.2402 sec.
# -------------
# Epoch 945/1500
# -------------
# （train）
# -------------
# epoch 945 || Epoch_D_Loss:0.1638 ||Epoch_G_Loss:0.0933 ||Epoch_E_Loss:0.1069
# timer:  0.2307 sec.
# -------------
# Epoch 946/1500
# -------------
# （train）
# -------------
# epoch 946 || Epoch_D_Loss:0.1408 ||Epoch_G_Loss:0.0982 ||Epoch_E_Loss:0.1147
# timer:  0.2325 sec.
# -------------
# Epoch 947/1500
# -------------
# （train）
# -------------
# epoch 947 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.1216 ||Epoch_E_Loss:0.1456
# timer:  0.2316 sec.
# -------------
# Epoch 948/1500
# -------------
# （train）
# -------------
# epoch 948 || Epoch_D_Loss:0.0866 ||Epoch_G_Loss:0.1418 ||Epoch_E_Loss:0.1552
# timer:  0.2312 sec.
# -------------
# Epoch 949/1500
# -------------
# （train）
# -------------
# epoch 949 || Epoch_D_Loss:0.1071 ||Epoch_G_Loss:0.1197 ||Epoch_E_Loss:0.1354
# timer:  0.2253 sec.
# -------------
# Epoch 950/1500
# -------------
# （train）
# -------------
# epoch 950 || Epoch_D_Loss:0.1439 ||Epoch_G_Loss:0.1064 ||Epoch_E_Loss:0.1064
# timer:  0.2358 sec.
# -------------
# Epoch 951/1500
# -------------
# （train）
# -------------
# epoch 951 || Epoch_D_Loss:0.1470 ||Epoch_G_Loss:0.0947 ||Epoch_E_Loss:0.1086
# timer:  0.2364 sec.
# -------------
# Epoch 952/1500
# -------------
# （train）
# -------------
# epoch 952 || Epoch_D_Loss:0.1272 ||Epoch_G_Loss:0.1110 ||Epoch_E_Loss:0.1176
# timer:  0.2283 sec.
# -------------
# Epoch 953/1500
# -------------
# （train）
# -------------
# epoch 953 || Epoch_D_Loss:0.1240 ||Epoch_G_Loss:0.1138 ||Epoch_E_Loss:0.1225
# timer:  0.2344 sec.
# -------------
# Epoch 954/1500
# -------------
# （train）
# -------------
# epoch 954 || Epoch_D_Loss:0.1185 ||Epoch_G_Loss:0.1072 ||Epoch_E_Loss:0.1255
# timer:  0.2353 sec.
# -------------
# Epoch 955/1500
# -------------
# （train）
# -------------
# epoch 955 || Epoch_D_Loss:0.1174 ||Epoch_G_Loss:0.1144 ||Epoch_E_Loss:0.1295
# timer:  0.2264 sec.
# -------------
# Epoch 956/1500
# -------------
# （train）
# -------------
# epoch 956 || Epoch_D_Loss:0.1169 ||Epoch_G_Loss:0.1181 ||Epoch_E_Loss:0.1229
# timer:  0.2429 sec.
# -------------
# Epoch 957/1500
# -------------
# （train）
# -------------
# epoch 957 || Epoch_D_Loss:0.1104 ||Epoch_G_Loss:0.1174 ||Epoch_E_Loss:0.1279
# timer:  0.2284 sec.
# -------------
# Epoch 958/1500
# -------------
# （train）
# -------------
# epoch 958 || Epoch_D_Loss:0.1091 ||Epoch_G_Loss:0.1120 ||Epoch_E_Loss:0.1348
# timer:  0.2306 sec.
# -------------
# Epoch 959/1500
# -------------
# （train）
# -------------
# epoch 959 || Epoch_D_Loss:0.1178 ||Epoch_G_Loss:0.1078 ||Epoch_E_Loss:0.1252
# timer:  0.2341 sec.
# -------------
# Epoch 960/1500
# -------------
# （train）
# -------------
# epoch 960 || Epoch_D_Loss:0.1246 ||Epoch_G_Loss:0.1129 ||Epoch_E_Loss:0.1164
# timer:  0.2328 sec.
# -------------
# Epoch 961/1500
# -------------
# （train）
# -------------
# epoch 961 || Epoch_D_Loss:0.1342 ||Epoch_G_Loss:0.0941 ||Epoch_E_Loss:0.1119
# timer:  0.2231 sec.
# -------------
# Epoch 962/1500
# -------------
# （train）
# -------------
# epoch 962 || Epoch_D_Loss:0.1459 ||Epoch_G_Loss:0.0918 ||Epoch_E_Loss:0.1069
# timer:  0.2250 sec.
# -------------
# Epoch 963/1500
# -------------
# （train）
# -------------
# epoch 963 || Epoch_D_Loss:0.1331 ||Epoch_G_Loss:0.0927 ||Epoch_E_Loss:0.1330
# timer:  0.2426 sec.
# -------------
# Epoch 964/1500
# -------------
# （train）
# -------------
# epoch 964 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1343 ||Epoch_E_Loss:0.1384
# timer:  0.2301 sec.
# -------------
# Epoch 965/1500
# -------------
# （train）
# -------------
# epoch 965 || Epoch_D_Loss:0.0922 ||Epoch_G_Loss:0.1409 ||Epoch_E_Loss:0.1451
# timer:  0.2290 sec.
# -------------
# Epoch 966/1500
# -------------
# （train）
# -------------
# epoch 966 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.1179 ||Epoch_E_Loss:0.1368
# timer:  0.2285 sec.
# -------------
# Epoch 967/1500
# -------------
# （train）
# -------------
# epoch 967 || Epoch_D_Loss:0.1274 ||Epoch_G_Loss:0.1026 ||Epoch_E_Loss:0.1141
# timer:  0.2329 sec.
# -------------
# Epoch 968/1500
# -------------
# （train）
# -------------
# epoch 968 || Epoch_D_Loss:0.1523 ||Epoch_G_Loss:0.0878 ||Epoch_E_Loss:0.1084
# timer:  0.2193 sec.
# -------------
# Epoch 969/1500
# -------------
# （train）
# -------------
# epoch 969 || Epoch_D_Loss:0.1409 ||Epoch_G_Loss:0.0934 ||Epoch_E_Loss:0.1118
# timer:  0.2398 sec.
# -------------
# Epoch 970/1500
# -------------
# （train）
# -------------
# epoch 970 || Epoch_D_Loss:0.1183 ||Epoch_G_Loss:0.1182 ||Epoch_E_Loss:0.1204
# timer:  0.2481 sec.
# -------------
# Epoch 971/1500
# -------------
# （train）
# -------------
# epoch 971 || Epoch_D_Loss:0.0951 ||Epoch_G_Loss:0.1181 ||Epoch_E_Loss:0.1393
# timer:  0.2297 sec.
# -------------
# Epoch 972/1500
# -------------
# （train）
# -------------
# epoch 972 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.1256 ||Epoch_E_Loss:0.1330
# timer:  0.2386 sec.
# -------------
# Epoch 973/1500
# -------------
# （train）
# -------------
# epoch 973 || Epoch_D_Loss:0.1183 ||Epoch_G_Loss:0.1222 ||Epoch_E_Loss:0.1159
# timer:  0.2337 sec.
# -------------
# Epoch 974/1500
# -------------
# （train）
# -------------
# epoch 974 || Epoch_D_Loss:0.1350 ||Epoch_G_Loss:0.0989 ||Epoch_E_Loss:0.1251
# timer:  0.2354 sec.
# -------------
# Epoch 975/1500
# -------------
# （train）
# -------------
# epoch 975 || Epoch_D_Loss:0.1171 ||Epoch_G_Loss:0.1070 ||Epoch_E_Loss:0.1210
# timer:  0.2346 sec.
# -------------
# Epoch 976/1500
# -------------
# （train）
# -------------
# epoch 976 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1192 ||Epoch_E_Loss:0.1225
# timer:  0.2336 sec.
# -------------
# Epoch 977/1500
# -------------
# （train）
# -------------
# epoch 977 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1150 ||Epoch_E_Loss:0.1369
# timer:  0.2241 sec.
# -------------
# Epoch 978/1500
# -------------
# （train）
# -------------
# epoch 978 || Epoch_D_Loss:0.1114 ||Epoch_G_Loss:0.1259 ||Epoch_E_Loss:0.1280
# timer:  0.2311 sec.
# -------------
# Epoch 979/1500
# -------------
# （train）
# -------------
# epoch 979 || Epoch_D_Loss:0.1176 ||Epoch_G_Loss:0.1218 ||Epoch_E_Loss:0.1211
# timer:  0.2271 sec.
# -------------
# Epoch 980/1500
# -------------
# （train）
# -------------
# epoch 980 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.1123 ||Epoch_E_Loss:0.1249
# timer:  0.2359 sec.
# -------------
# Epoch 981/1500
# -------------
# （train）
# -------------
# epoch 981 || Epoch_D_Loss:0.1235 ||Epoch_G_Loss:0.1062 ||Epoch_E_Loss:0.1184
# timer:  0.2332 sec.
# -------------
# Epoch 982/1500
# -------------
# （train）
# -------------
# epoch 982 || Epoch_D_Loss:0.1204 ||Epoch_G_Loss:0.1200 ||Epoch_E_Loss:0.1182
# timer:  0.2320 sec.
# -------------
# Epoch 983/1500
# -------------
# （train）
# -------------
# epoch 983 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1058 ||Epoch_E_Loss:0.1300
# timer:  0.2313 sec.
# -------------
# Epoch 984/1500
# -------------
# （train）
# -------------
# epoch 984 || Epoch_D_Loss:0.1127 ||Epoch_G_Loss:0.1192 ||Epoch_E_Loss:0.1264
# timer:  0.2297 sec.
# -------------
# Epoch 985/1500
# -------------
# （train）
# -------------
# epoch 985 || Epoch_D_Loss:0.1203 ||Epoch_G_Loss:0.1199 ||Epoch_E_Loss:0.1185
# timer:  0.2315 sec.
# -------------
# Epoch 986/1500
# -------------
# （train）
# -------------
# epoch 986 || Epoch_D_Loss:0.1234 ||Epoch_G_Loss:0.0988 ||Epoch_E_Loss:0.1299
# timer:  0.2248 sec.
# -------------
# Epoch 987/1500
# -------------
# （train）
# -------------
# epoch 987 || Epoch_D_Loss:0.1201 ||Epoch_G_Loss:0.1183 ||Epoch_E_Loss:0.1210
# timer:  0.2412 sec.
# -------------
# Epoch 988/1500
# -------------
# （train）
# -------------
# epoch 988 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1177 ||Epoch_E_Loss:0.1312
# timer:  0.2293 sec.
# -------------
# Epoch 989/1500
# -------------
# （train）
# -------------
# epoch 989 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.1176 ||Epoch_E_Loss:0.1302
# timer:  0.2347 sec.
# -------------
# Epoch 990/1500
# -------------
# （train）
# -------------
# epoch 990 || Epoch_D_Loss:0.1110 ||Epoch_G_Loss:0.1223 ||Epoch_E_Loss:0.1314
# timer:  0.2298 sec.
# -------------
# Epoch 991/1500
# -------------
# （train）
# -------------
# epoch 991 || Epoch_D_Loss:0.1159 ||Epoch_G_Loss:0.1167 ||Epoch_E_Loss:0.1216
# timer:  0.2364 sec.
# -------------
# Epoch 992/1500
# -------------
# （train）
# -------------
# epoch 992 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.1025 ||Epoch_E_Loss:0.1289
# timer:  0.2314 sec.
# -------------
# Epoch 993/1500
# -------------
# （train）
# -------------
# epoch 993 || Epoch_D_Loss:0.1281 ||Epoch_G_Loss:0.1166 ||Epoch_E_Loss:0.1225
# timer:  0.2367 sec.
# -------------
# Epoch 994/1500
# -------------
# （train）
# -------------
# epoch 994 || Epoch_D_Loss:0.1165 ||Epoch_G_Loss:0.1174 ||Epoch_E_Loss:0.1290
# timer:  0.2277 sec.
# -------------
# Epoch 995/1500
# -------------
# （train）
# -------------
# epoch 995 || Epoch_D_Loss:0.1127 ||Epoch_G_Loss:0.1169 ||Epoch_E_Loss:0.1255
# timer:  0.2436 sec.
# -------------
# Epoch 996/1500
# -------------
# （train）
# -------------
# epoch 996 || Epoch_D_Loss:0.1147 ||Epoch_G_Loss:0.1204 ||Epoch_E_Loss:0.1316
# timer:  0.2317 sec.
# -------------
# Epoch 997/1500
# -------------
# （train）
# -------------
# epoch 997 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1133 ||Epoch_E_Loss:0.1330
# timer:  0.2384 sec.
# -------------
# Epoch 998/1500
# -------------
# （train）
# -------------
# epoch 998 || Epoch_D_Loss:0.1280 ||Epoch_G_Loss:0.1154 ||Epoch_E_Loss:0.1189
# timer:  0.2338 sec.
# -------------
# Epoch 999/1500
# -------------
# （train）
# -------------
# epoch 999 || Epoch_D_Loss:0.1250 ||Epoch_G_Loss:0.1177 ||Epoch_E_Loss:0.1180
# timer:  0.2315 sec.
# -------------
# Epoch 1000/1500
# -------------
# （train）
# -------------
# epoch 1000 || Epoch_D_Loss:0.1252 ||Epoch_G_Loss:0.1079 ||Epoch_E_Loss:0.1219
# timer:  0.2344 sec.
# -------------
# Epoch 1001/1500
# -------------
# （train）
# -------------
# epoch 1001 || Epoch_D_Loss:0.1155 ||Epoch_G_Loss:0.1143 ||Epoch_E_Loss:0.1262
# timer:  0.2391 sec.
# -------------
# Epoch 1002/1500
# -------------
# （train）
# -------------
# epoch 1002 || Epoch_D_Loss:0.1058 ||Epoch_G_Loss:0.1301 ||Epoch_E_Loss:0.1337
# timer:  0.2326 sec.
# -------------
# Epoch 1003/1500
# -------------
# （train）
# -------------
# epoch 1003 || Epoch_D_Loss:0.1031 ||Epoch_G_Loss:0.1329 ||Epoch_E_Loss:0.1278
# timer:  0.2304 sec.
# -------------
# Epoch 1004/1500
# -------------
# （train）
# -------------
# epoch 1004 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.1297 ||Epoch_E_Loss:0.1280
# timer:  0.2399 sec.
# -------------
# Epoch 1005/1500
# -------------
# （train）
# -------------
# epoch 1005 || Epoch_D_Loss:0.1375 ||Epoch_G_Loss:0.1068 ||Epoch_E_Loss:0.1273
# timer:  0.2320 sec.
# -------------
# Epoch 1006/1500
# -------------
# （train）
# -------------
# epoch 1006 || Epoch_D_Loss:0.1403 ||Epoch_G_Loss:0.1061 ||Epoch_E_Loss:0.1019
# timer:  0.2374 sec.
# -------------
# Epoch 1007/1500
# -------------
# （train）
# -------------
# epoch 1007 || Epoch_D_Loss:0.1333 ||Epoch_G_Loss:0.0995 ||Epoch_E_Loss:0.1211
# timer:  0.2360 sec.
# -------------
# Epoch 1008/1500
# -------------
# （train）
# -------------
# epoch 1008 || Epoch_D_Loss:0.1215 ||Epoch_G_Loss:0.1136 ||Epoch_E_Loss:0.1174
# timer:  0.2329 sec.
# -------------
# Epoch 1009/1500
# -------------
# （train）
# -------------
# epoch 1009 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.1178 ||Epoch_E_Loss:0.1261
# timer:  0.2356 sec.
# -------------
# Epoch 1010/1500
# -------------
# （train）
# -------------
# epoch 1010 || Epoch_D_Loss:0.1084 ||Epoch_G_Loss:0.1371 ||Epoch_E_Loss:0.1240
# timer:  0.2445 sec.
# -------------
# Epoch 1011/1500
# -------------
# （train）
# -------------
# epoch 1011 || Epoch_D_Loss:0.1196 ||Epoch_G_Loss:0.1071 ||Epoch_E_Loss:0.1334
# timer:  0.2309 sec.
# -------------
# Epoch 1012/1500
# -------------
# （train）
# -------------
# epoch 1012 || Epoch_D_Loss:0.1309 ||Epoch_G_Loss:0.1073 ||Epoch_E_Loss:0.1157
# timer:  0.2324 sec.
# -------------
# Epoch 1013/1500
# -------------
# （train）
# -------------
# epoch 1013 || Epoch_D_Loss:0.1187 ||Epoch_G_Loss:0.1091 ||Epoch_E_Loss:0.1213
# timer:  0.2351 sec.
# -------------
# Epoch 1014/1500
# -------------
# （train）
# -------------
# epoch 1014 || Epoch_D_Loss:0.1240 ||Epoch_G_Loss:0.1119 ||Epoch_E_Loss:0.1168
# timer:  0.2456 sec.
# -------------
# Epoch 1015/1500
# -------------
# （train）
# -------------
# epoch 1015 || Epoch_D_Loss:0.1315 ||Epoch_G_Loss:0.1086 ||Epoch_E_Loss:0.1166
# timer:  0.2315 sec.
# -------------
# Epoch 1016/1500
# -------------
# （train）
# -------------
# epoch 1016 || Epoch_D_Loss:0.1242 ||Epoch_G_Loss:0.1063 ||Epoch_E_Loss:0.1202
# timer:  0.2315 sec.
# -------------
# Epoch 1017/1500
# -------------
# （train）
# -------------
# epoch 1017 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1135 ||Epoch_E_Loss:0.1246
# timer:  0.2380 sec.
# -------------
# Epoch 1018/1500
# -------------
# （train）
# -------------
# epoch 1018 || Epoch_D_Loss:0.1160 ||Epoch_G_Loss:0.1270 ||Epoch_E_Loss:0.1240
# timer:  0.2375 sec.
# -------------
# Epoch 1019/1500
# -------------
# （train）
# -------------
# epoch 1019 || Epoch_D_Loss:0.1131 ||Epoch_G_Loss:0.1163 ||Epoch_E_Loss:0.1204
# timer:  0.2484 sec.
# -------------
# Epoch 1020/1500
# -------------
# （train）
# -------------
# epoch 1020 || Epoch_D_Loss:0.1268 ||Epoch_G_Loss:0.1135 ||Epoch_E_Loss:0.1152
# timer:  0.2321 sec.
# -------------
# Epoch 1021/1500
# -------------
# （train）
# -------------
# epoch 1021 || Epoch_D_Loss:0.1212 ||Epoch_G_Loss:0.1002 ||Epoch_E_Loss:0.1182
# timer:  0.2350 sec.
# -------------
# Epoch 1022/1500
# -------------
# （train）
# -------------
# epoch 1022 || Epoch_D_Loss:0.1307 ||Epoch_G_Loss:0.1032 ||Epoch_E_Loss:0.1086
# timer:  0.2296 sec.
# -------------
# Epoch 1023/1500
# -------------
# （train）
# -------------
# epoch 1023 || Epoch_D_Loss:0.1254 ||Epoch_G_Loss:0.1043 ||Epoch_E_Loss:0.1162
# timer:  0.2369 sec.
# -------------
# Epoch 1024/1500
# -------------
# （train）
# -------------
# epoch 1024 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1129 ||Epoch_E_Loss:0.1217
# timer:  0.2300 sec.
# -------------
# Epoch 1025/1500
# -------------
# （train）
# -------------
# epoch 1025 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.1229 ||Epoch_E_Loss:0.1299
# timer:  0.2343 sec.
# -------------
# Epoch 1026/1500
# -------------
# （train）
# -------------
# epoch 1026 || Epoch_D_Loss:0.0955 ||Epoch_G_Loss:0.1294 ||Epoch_E_Loss:0.1332
# timer:  0.2532 sec.
# -------------
# Epoch 1027/1500
# -------------
# （train）
# -------------
# epoch 1027 || Epoch_D_Loss:0.0967 ||Epoch_G_Loss:0.1259 ||Epoch_E_Loss:0.1384
# timer:  0.2328 sec.
# -------------
# Epoch 1028/1500
# -------------
# （train）
# -------------
# epoch 1028 || Epoch_D_Loss:0.1073 ||Epoch_G_Loss:0.1084 ||Epoch_E_Loss:0.1275
# timer:  0.2346 sec.
# -------------
# Epoch 1029/1500
# -------------
# （train）
# -------------
# epoch 1029 || Epoch_D_Loss:0.1282 ||Epoch_G_Loss:0.1052 ||Epoch_E_Loss:0.1115
# timer:  0.2292 sec.
# -------------
# Epoch 1030/1500
# -------------
# （train）
# -------------
# epoch 1030 || Epoch_D_Loss:0.1335 ||Epoch_G_Loss:0.0998 ||Epoch_E_Loss:0.1076
# timer:  0.2366 sec.
# -------------
# Epoch 1031/1500
# -------------
# （train）
# -------------
# epoch 1031 || Epoch_D_Loss:0.1271 ||Epoch_G_Loss:0.0984 ||Epoch_E_Loss:0.1142
# timer:  0.2388 sec.
# -------------
# Epoch 1032/1500
# -------------
# （train）
# -------------
# epoch 1032 || Epoch_D_Loss:0.1107 ||Epoch_G_Loss:0.1220 ||Epoch_E_Loss:0.1197
# timer:  0.2311 sec.
# -------------
# Epoch 1033/1500
# -------------
# （train）
# -------------
# epoch 1033 || Epoch_D_Loss:0.0960 ||Epoch_G_Loss:0.1211 ||Epoch_E_Loss:0.1348
# timer:  0.2324 sec.
# -------------
# Epoch 1034/1500
# -------------
# （train）
# -------------
# epoch 1034 || Epoch_D_Loss:0.0995 ||Epoch_G_Loss:0.1299 ||Epoch_E_Loss:0.1332
# timer:  0.2393 sec.
# -------------
# Epoch 1035/1500
# -------------
# （train）
# -------------
# epoch 1035 || Epoch_D_Loss:0.1034 ||Epoch_G_Loss:0.1243 ||Epoch_E_Loss:0.1277
# timer:  0.2329 sec.
# -------------
# Epoch 1036/1500
# -------------
# （train）
# -------------
# epoch 1036 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.1115 ||Epoch_E_Loss:0.1260
# timer:  0.2312 sec.
# -------------
# Epoch 1037/1500
# -------------
# （train）
# -------------
# epoch 1037 || Epoch_D_Loss:0.1284 ||Epoch_G_Loss:0.1127 ||Epoch_E_Loss:0.1092
# timer:  0.2409 sec.
# -------------
# Epoch 1038/1500
# -------------
# （train）
# -------------
# epoch 1038 || Epoch_D_Loss:0.1255 ||Epoch_G_Loss:0.1088 ||Epoch_E_Loss:0.1187
# timer:  0.2316 sec.
# -------------
# Epoch 1039/1500
# -------------
# （train）
# -------------
# epoch 1039 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.1103 ||Epoch_E_Loss:0.1249
# timer:  0.2348 sec.
# -------------
# Epoch 1040/1500
# -------------
# （train）
# -------------
# epoch 1040 || Epoch_D_Loss:0.1049 ||Epoch_G_Loss:0.1188 ||Epoch_E_Loss:0.1244
# timer:  0.2304 sec.
# -------------
# Epoch 1041/1500
# -------------
# （train）
# -------------
# epoch 1041 || Epoch_D_Loss:0.1073 ||Epoch_G_Loss:0.1220 ||Epoch_E_Loss:0.1289
# timer:  0.2353 sec.
# -------------
# Epoch 1042/1500
# -------------
# （train）
# -------------
# epoch 1042 || Epoch_D_Loss:0.1024 ||Epoch_G_Loss:0.1236 ||Epoch_E_Loss:0.1356
# timer:  0.2301 sec.
# -------------
# Epoch 1043/1500
# -------------
# （train）
# -------------
# epoch 1043 || Epoch_D_Loss:0.1021 ||Epoch_G_Loss:0.1236 ||Epoch_E_Loss:0.1303
# timer:  0.2440 sec.
# -------------
# Epoch 1044/1500
# -------------
# （train）
# -------------
# epoch 1044 || Epoch_D_Loss:0.1057 ||Epoch_G_Loss:0.1273 ||Epoch_E_Loss:0.1236
# timer:  0.2350 sec.
# -------------
# Epoch 1045/1500
# -------------
# （train）
# -------------
# epoch 1045 || Epoch_D_Loss:0.1225 ||Epoch_G_Loss:0.1017 ||Epoch_E_Loss:0.1239
# timer:  0.2320 sec.
# -------------
# Epoch 1046/1500
# -------------
# （train）
# -------------
# epoch 1046 || Epoch_D_Loss:0.1261 ||Epoch_G_Loss:0.1102 ||Epoch_E_Loss:0.1169
# timer:  0.2268 sec.
# -------------
# Epoch 1047/1500
# -------------
# （train）
# -------------
# epoch 1047 || Epoch_D_Loss:0.1200 ||Epoch_G_Loss:0.1144 ||Epoch_E_Loss:0.1209
# timer:  0.2376 sec.
# -------------
# Epoch 1048/1500
# -------------
# （train）
# -------------
# epoch 1048 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.1222 ||Epoch_E_Loss:0.1307
# timer:  0.2364 sec.
# -------------
# Epoch 1049/1500
# -------------
# （train）
# -------------
# epoch 1049 || Epoch_D_Loss:0.0998 ||Epoch_G_Loss:0.1246 ||Epoch_E_Loss:0.1359
# timer:  0.2508 sec.
# -------------
# Epoch 1050/1500
# -------------
# （train）
# -------------
# epoch 1050 || Epoch_D_Loss:0.1024 ||Epoch_G_Loss:0.1293 ||Epoch_E_Loss:0.1319
# timer:  0.2264 sec.
# -------------
# Epoch 1051/1500
# -------------
# （train）
# -------------
# epoch 1051 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.1267 ||Epoch_E_Loss:0.1336
# timer:  0.2336 sec.
# -------------
# Epoch 1052/1500
# -------------
# （train）
# -------------
# epoch 1052 || Epoch_D_Loss:0.1102 ||Epoch_G_Loss:0.1238 ||Epoch_E_Loss:0.1290
# timer:  0.2446 sec.
# -------------
# Epoch 1053/1500
# -------------
# （train）
# -------------
# epoch 1053 || Epoch_D_Loss:0.1287 ||Epoch_G_Loss:0.1008 ||Epoch_E_Loss:0.1121
# timer:  0.2289 sec.
# -------------
# Epoch 1054/1500
# -------------
# （train）
# -------------
# epoch 1054 || Epoch_D_Loss:0.1346 ||Epoch_G_Loss:0.0934 ||Epoch_E_Loss:0.1120
# timer:  0.2382 sec.
# -------------
# Epoch 1055/1500
# -------------
# （train）
# -------------
# epoch 1055 || Epoch_D_Loss:0.1315 ||Epoch_G_Loss:0.1027 ||Epoch_E_Loss:0.1149
# timer:  0.2401 sec.
# -------------
# Epoch 1056/1500
# -------------
# （train）
# -------------
# epoch 1056 || Epoch_D_Loss:0.1051 ||Epoch_G_Loss:0.1242 ||Epoch_E_Loss:0.1298
# timer:  0.2327 sec.
# -------------
# Epoch 1057/1500
# -------------
# （train）
# -------------
# epoch 1057 || Epoch_D_Loss:0.0975 ||Epoch_G_Loss:0.1286 ||Epoch_E_Loss:0.1367
# timer:  0.2395 sec.
# -------------
# Epoch 1058/1500
# -------------
# （train）
# -------------
# epoch 1058 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.1412 ||Epoch_E_Loss:0.1304
# timer:  0.2362 sec.
# -------------
# Epoch 1059/1500
# -------------
# （train）
# -------------
# epoch 1059 || Epoch_D_Loss:0.1110 ||Epoch_G_Loss:0.1242 ||Epoch_E_Loss:0.1204
# timer:  0.2258 sec.
# -------------
# Epoch 1060/1500
# -------------
# （train）
# -------------
# epoch 1060 || Epoch_D_Loss:0.1283 ||Epoch_G_Loss:0.1061 ||Epoch_E_Loss:0.1205
# timer:  0.2716 sec.
# -------------
# Epoch 1061/1500
# -------------
# （train）
# -------------
# epoch 1061 || Epoch_D_Loss:0.1253 ||Epoch_G_Loss:0.1043 ||Epoch_E_Loss:0.1115
# timer:  0.2336 sec.
# -------------
# Epoch 1062/1500
# -------------
# （train）
# -------------
# epoch 1062 || Epoch_D_Loss:0.1221 ||Epoch_G_Loss:0.1084 ||Epoch_E_Loss:0.1125
# timer:  0.2398 sec.
# -------------
# Epoch 1063/1500
# -------------
# （train）
# -------------
# epoch 1063 || Epoch_D_Loss:0.1175 ||Epoch_G_Loss:0.1102 ||Epoch_E_Loss:0.1224
# timer:  0.2302 sec.
# -------------
# Epoch 1064/1500
# -------------
# （train）
# -------------
# epoch 1064 || Epoch_D_Loss:0.1103 ||Epoch_G_Loss:0.1159 ||Epoch_E_Loss:0.1202
# timer:  0.2433 sec.
# -------------
# Epoch 1065/1500
# -------------
# （train）
# -------------
# epoch 1065 || Epoch_D_Loss:0.1007 ||Epoch_G_Loss:0.1279 ||Epoch_E_Loss:0.1294
# timer:  0.2417 sec.
# -------------
# Epoch 1066/1500
# -------------
# （train）
# -------------
# epoch 1066 || Epoch_D_Loss:0.0926 ||Epoch_G_Loss:0.1187 ||Epoch_E_Loss:0.1414
# timer:  0.2375 sec.
# -------------
# Epoch 1067/1500
# -------------
# （train）
# -------------
# epoch 1067 || Epoch_D_Loss:0.0969 ||Epoch_G_Loss:0.1334 ||Epoch_E_Loss:0.1320
# timer:  0.2324 sec.
# -------------
# Epoch 1068/1500
# -------------
# （train）
# -------------
# epoch 1068 || Epoch_D_Loss:0.0992 ||Epoch_G_Loss:0.1201 ||Epoch_E_Loss:0.1351
# timer:  0.2340 sec.
# -------------
# Epoch 1069/1500
# -------------
# （train）
# -------------
# epoch 1069 || Epoch_D_Loss:0.1037 ||Epoch_G_Loss:0.1231 ||Epoch_E_Loss:0.1261
# timer:  0.2339 sec.
# -------------
# Epoch 1070/1500
# -------------
# （train）
# -------------
# epoch 1070 || Epoch_D_Loss:0.1185 ||Epoch_G_Loss:0.1152 ||Epoch_E_Loss:0.1167
# timer:  0.2261 sec.
# -------------
# Epoch 1071/1500
# -------------
# （train）
# -------------
# epoch 1071 || Epoch_D_Loss:0.1261 ||Epoch_G_Loss:0.0984 ||Epoch_E_Loss:0.1125
# timer:  0.2329 sec.
# -------------
# Epoch 1072/1500
# -------------
# （train）
# -------------
# epoch 1072 || Epoch_D_Loss:0.1242 ||Epoch_G_Loss:0.1084 ||Epoch_E_Loss:0.1071
# timer:  0.2329 sec.
# -------------
# Epoch 1073/1500
# -------------
# （train）
# -------------
# epoch 1073 || Epoch_D_Loss:0.1043 ||Epoch_G_Loss:0.1144 ||Epoch_E_Loss:0.1274
# timer:  0.2350 sec.
# -------------
# Epoch 1074/1500
# -------------
# （train）
# -------------
# epoch 1074 || Epoch_D_Loss:0.0941 ||Epoch_G_Loss:0.1427 ||Epoch_E_Loss:0.1340
# timer:  0.2304 sec.
# -------------
# Epoch 1075/1500
# -------------
# （train）
# -------------
# epoch 1075 || Epoch_D_Loss:0.0839 ||Epoch_G_Loss:0.1352 ||Epoch_E_Loss:0.1512
# timer:  0.2344 sec.
# -------------
# Epoch 1076/1500
# -------------
# （train）
# -------------
# epoch 1076 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1311 ||Epoch_E_Loss:0.1349
# timer:  0.2344 sec.
# -------------
# Epoch 1077/1500
# -------------
# （train）
# -------------
# epoch 1077 || Epoch_D_Loss:0.1049 ||Epoch_G_Loss:0.1205 ||Epoch_E_Loss:0.1280
# timer:  0.2299 sec.
# -------------
# Epoch 1078/1500
# -------------
# ...
# timer:  0.2402 sec.
# -------------
# Epoch 1403/1500
# -------------
# （train）
# -------------
# epoch 1403 || Epoch_D_Loss:0.0944 ||Epoch_G_Loss:0.1441 ||Epoch_E_Loss:0.1451
# timer:  0.2327 sec.
# -------------
# Epoch 1404/1500
# -------------
# （train）
# -------------
# epoch 1404 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.1554 ||Epoch_E_Loss:0.1477
# timer:  0.2532 sec.
# -------------
# Epoch 1405/1500
# -------------
# （train）
# -------------
# epoch 1405 || Epoch_D_Loss:0.0953 ||Epoch_G_Loss:0.1371 ||Epoch_E_Loss:0.1503
# timer:  0.2352 sec.
# -------------
# Epoch 1406/1500
# -------------
# （train）
# -------------
# epoch 1406 || Epoch_D_Loss:0.0939 ||Epoch_G_Loss:0.1382 ||Epoch_E_Loss:0.1536
# timer:  0.2357 sec.
# -------------
# Epoch 1407/1500
# -------------
# （train）
# -------------
# epoch 1407 || Epoch_D_Loss:0.0939 ||Epoch_G_Loss:0.1540 ||Epoch_E_Loss:0.1519
# timer:  0.2290 sec.
# -------------
# Epoch 1408/1500
# -------------
# （train）
# -------------
# epoch 1408 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1523
# timer:  0.2371 sec.
# -------------
# Epoch 1409/1500
# -------------
# （train）
# -------------
# epoch 1409 || Epoch_D_Loss:0.1040 ||Epoch_G_Loss:0.1312 ||Epoch_E_Loss:0.1452
# timer:  0.2374 sec.
# -------------
# Epoch 1410/1500
# -------------
# （train）
# -------------
# epoch 1410 || Epoch_D_Loss:0.0986 ||Epoch_G_Loss:0.1329 ||Epoch_E_Loss:0.1510
# timer:  0.2319 sec.
# -------------
# Epoch 1411/1500
# -------------
# （train）
# -------------
# epoch 1411 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1318 ||Epoch_E_Loss:0.1637
# timer:  0.2333 sec.
# -------------
# Epoch 1412/1500
# -------------
# （train）
# -------------
# epoch 1412 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1522 ||Epoch_E_Loss:0.1587
# timer:  0.2296 sec.
# -------------
# Epoch 1413/1500
# -------------
# （train）
# -------------
# epoch 1413 || Epoch_D_Loss:0.1018 ||Epoch_G_Loss:0.1571 ||Epoch_E_Loss:0.1507
# timer:  0.2290 sec.
# -------------
# Epoch 1414/1500
# -------------
# （train）
# -------------
# epoch 1414 || Epoch_D_Loss:0.0956 ||Epoch_G_Loss:0.1532 ||Epoch_E_Loss:0.1559
# timer:  0.2316 sec.
# -------------
# Epoch 1415/1500
# -------------
# （train）
# -------------
# epoch 1415 || Epoch_D_Loss:0.0966 ||Epoch_G_Loss:0.1639 ||Epoch_E_Loss:0.1416
# timer:  0.2329 sec.
# -------------
# Epoch 1416/1500
# -------------
# （train）
# -------------
# epoch 1416 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1310 ||Epoch_E_Loss:0.1545
# timer:  0.2338 sec.
# -------------
# Epoch 1417/1500
# -------------
# （train）
# -------------
# epoch 1417 || Epoch_D_Loss:0.1067 ||Epoch_G_Loss:0.1301 ||Epoch_E_Loss:0.1489
# timer:  0.2324 sec.
# -------------
# Epoch 1418/1500
# -------------
# （train）
# -------------
# epoch 1418 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1397
# timer:  0.2305 sec.
# -------------
# Epoch 1419/1500
# -------------
# （train）
# -------------
# epoch 1419 || Epoch_D_Loss:0.0984 ||Epoch_G_Loss:0.1311 ||Epoch_E_Loss:0.1591
# timer:  0.2252 sec.
# -------------
# Epoch 1420/1500
# -------------
# （train）
# -------------
# epoch 1420 || Epoch_D_Loss:0.0989 ||Epoch_G_Loss:0.1442 ||Epoch_E_Loss:0.1393
# timer:  0.2243 sec.
# -------------
# Epoch 1421/1500
# -------------
# （train）
# -------------
# epoch 1421 || Epoch_D_Loss:0.0996 ||Epoch_G_Loss:0.1365 ||Epoch_E_Loss:0.1574
# timer:  0.2322 sec.
# -------------
# Epoch 1422/1500
# -------------
# （train）
# -------------
# epoch 1422 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1535 ||Epoch_E_Loss:0.1458
# timer:  0.2293 sec.
# -------------
# Epoch 1423/1500
# -------------
# （train）
# -------------
# epoch 1423 || Epoch_D_Loss:0.0966 ||Epoch_G_Loss:0.1370 ||Epoch_E_Loss:0.1546
# timer:  0.2276 sec.
# -------------
# Epoch 1424/1500
# -------------
# （train）
# -------------
# epoch 1424 || Epoch_D_Loss:0.0891 ||Epoch_G_Loss:0.1433 ||Epoch_E_Loss:0.1532
# timer:  0.2358 sec.
# -------------
# Epoch 1425/1500
# -------------
# （train）
# -------------
# epoch 1425 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1539 ||Epoch_E_Loss:0.1502
# timer:  0.2250 sec.
# -------------
# Epoch 1426/1500
# -------------
# （train）
# -------------
# epoch 1426 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1463 ||Epoch_E_Loss:0.1577
# timer:  0.2341 sec.
# -------------
# Epoch 1427/1500
# -------------
# （train）
# -------------
# epoch 1427 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1490 ||Epoch_E_Loss:0.1454
# timer:  0.2366 sec.
# -------------
# Epoch 1428/1500
# -------------
# （train）
# -------------
# epoch 1428 || Epoch_D_Loss:0.1055 ||Epoch_G_Loss:0.1432 ||Epoch_E_Loss:0.1399
# timer:  0.2376 sec.
# -------------
# Epoch 1429/1500
# -------------
# （train）
# -------------
# epoch 1429 || Epoch_D_Loss:0.0977 ||Epoch_G_Loss:0.1257 ||Epoch_E_Loss:0.1462
# timer:  0.2269 sec.
# -------------
# Epoch 1430/1500
# -------------
# （train）
# -------------
# epoch 1430 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1404 ||Epoch_E_Loss:0.1496
# timer:  0.2446 sec.
# -------------
# Epoch 1431/1500
# -------------
# （train）
# -------------
# epoch 1431 || Epoch_D_Loss:0.0850 ||Epoch_G_Loss:0.1655 ||Epoch_E_Loss:0.1646
# timer:  0.2292 sec.
# -------------
# Epoch 1432/1500
# -------------
# （train）
# -------------
# epoch 1432 || Epoch_D_Loss:0.0818 ||Epoch_G_Loss:0.1557 ||Epoch_E_Loss:0.1656
# timer:  0.2308 sec.
# -------------
# Epoch 1433/1500
# -------------
# （train）
# -------------
# epoch 1433 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1493 ||Epoch_E_Loss:0.1621
# timer:  0.2383 sec.
# -------------
# Epoch 1434/1500
# -------------
# （train）
# -------------
# epoch 1434 || Epoch_D_Loss:0.0970 ||Epoch_G_Loss:0.1431 ||Epoch_E_Loss:0.1436
# timer:  0.2297 sec.
# -------------
# Epoch 1435/1500
# -------------
# （train）
# -------------
# epoch 1435 || Epoch_D_Loss:0.1022 ||Epoch_G_Loss:0.1271 ||Epoch_E_Loss:0.1463
# timer:  0.2326 sec.
# -------------
# Epoch 1436/1500
# -------------
# （train）
# -------------
# epoch 1436 || Epoch_D_Loss:0.1008 ||Epoch_G_Loss:0.1252 ||Epoch_E_Loss:0.1465
# timer:  0.2378 sec.
# -------------
# Epoch 1437/1500
# -------------
# （train）
# -------------
# epoch 1437 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.1468 ||Epoch_E_Loss:0.1536
# timer:  0.2410 sec.
# -------------
# Epoch 1438/1500
# -------------
# （train）
# -------------
# epoch 1438 || Epoch_D_Loss:0.0865 ||Epoch_G_Loss:0.1636 ||Epoch_E_Loss:0.1594
# timer:  0.2346 sec.
# -------------
# Epoch 1439/1500
# -------------
# （train）
# -------------
# epoch 1439 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.1490 ||Epoch_E_Loss:0.1596
# timer:  0.2412 sec.
# -------------
# Epoch 1440/1500
# -------------
# （train）
# -------------
# epoch 1440 || Epoch_D_Loss:0.1042 ||Epoch_G_Loss:0.1351 ||Epoch_E_Loss:0.1494
# timer:  0.2307 sec.
# -------------
# Epoch 1441/1500
# -------------
# （train）
# -------------
# epoch 1441 || Epoch_D_Loss:0.1061 ||Epoch_G_Loss:0.1283 ||Epoch_E_Loss:0.1442
# timer:  0.2382 sec.
# -------------
# Epoch 1442/1500
# -------------
# （train）
# -------------
# epoch 1442 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.1367 ||Epoch_E_Loss:0.1500
# timer:  0.2300 sec.
# -------------
# Epoch 1443/1500
# -------------
# （train）
# -------------
# epoch 1443 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.1404 ||Epoch_E_Loss:0.1672
# timer:  0.2435 sec.
# -------------
# Epoch 1444/1500
# -------------
# （train）
# -------------
# epoch 1444 || Epoch_D_Loss:0.0850 ||Epoch_G_Loss:0.1549 ||Epoch_E_Loss:0.1649
# timer:  0.2351 sec.
# -------------
# Epoch 1445/1500
# -------------
# （train）
# -------------
# epoch 1445 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.1327 ||Epoch_E_Loss:0.1621
# timer:  0.2239 sec.
# -------------
# Epoch 1446/1500
# -------------
# （train）
# -------------
# epoch 1446 || Epoch_D_Loss:0.1095 ||Epoch_G_Loss:0.1491 ||Epoch_E_Loss:0.1433
# timer:  0.2331 sec.
# -------------
# Epoch 1447/1500
# -------------
# （train）
# -------------
# epoch 1447 || Epoch_D_Loss:0.0955 ||Epoch_G_Loss:0.1392 ||Epoch_E_Loss:0.1596
# timer:  0.2366 sec.
# -------------
# Epoch 1448/1500
# -------------
# （train）
# -------------
# epoch 1448 || Epoch_D_Loss:0.0962 ||Epoch_G_Loss:0.1500 ||Epoch_E_Loss:0.1556
# timer:  0.2350 sec.
# -------------
# Epoch 1449/1500
# -------------
# （train）
# -------------
# epoch 1449 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1342 ||Epoch_E_Loss:0.1598
# timer:  0.2349 sec.
# -------------
# Epoch 1450/1500
# -------------
# （train）
# -------------
# epoch 1450 || Epoch_D_Loss:0.1083 ||Epoch_G_Loss:0.1469 ||Epoch_E_Loss:0.1482
# timer:  0.2319 sec.
# -------------
# Epoch 1451/1500
# -------------
# （train）
# -------------
# epoch 1451 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1489 ||Epoch_E_Loss:0.1636
# timer:  0.2246 sec.
# -------------
# Epoch 1452/1500
# -------------
# （train）
# -------------
# epoch 1452 || Epoch_D_Loss:0.0965 ||Epoch_G_Loss:0.1438 ||Epoch_E_Loss:0.1520
# timer:  0.2413 sec.
# -------------
# Epoch 1453/1500
# -------------
# （train）
# -------------
# epoch 1453 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1255 ||Epoch_E_Loss:0.1480
# timer:  0.2298 sec.
# -------------
# Epoch 1454/1500
# -------------
# （train）
# -------------
# epoch 1454 || Epoch_D_Loss:0.1017 ||Epoch_G_Loss:0.1535 ||Epoch_E_Loss:0.1499
# timer:  0.2401 sec.
# -------------
# Epoch 1455/1500
# -------------
# （train）
# -------------
# epoch 1455 || Epoch_D_Loss:0.0963 ||Epoch_G_Loss:0.1372 ||Epoch_E_Loss:0.1611
# timer:  0.2282 sec.
# -------------
# Epoch 1456/1500
# -------------
# （train）
# -------------
# epoch 1456 || Epoch_D_Loss:0.0939 ||Epoch_G_Loss:0.1431 ||Epoch_E_Loss:0.1564
# timer:  0.2454 sec.
# -------------
# Epoch 1457/1500
# -------------
# （train）
# -------------
# epoch 1457 || Epoch_D_Loss:0.0984 ||Epoch_G_Loss:0.1373 ||Epoch_E_Loss:0.1600
# timer:  0.2284 sec.
# -------------
# Epoch 1458/1500
# -------------
# （train）
# -------------
# epoch 1458 || Epoch_D_Loss:0.1237 ||Epoch_G_Loss:0.1171 ||Epoch_E_Loss:0.1539
# timer:  0.2237 sec.
# -------------
# Epoch 1459/1500
# -------------
# （train）
# -------------
# epoch 1459 || Epoch_D_Loss:0.1039 ||Epoch_G_Loss:0.1402 ||Epoch_E_Loss:0.1627
# timer:  0.2342 sec.
# -------------
# Epoch 1460/1500
# -------------
# （train）
# -------------
# epoch 1460 || Epoch_D_Loss:0.1090 ||Epoch_G_Loss:0.1316 ||Epoch_E_Loss:0.1666
# timer:  0.2386 sec.
# -------------
# Epoch 1461/1500
# -------------
# （train）
# -------------
# epoch 1461 || Epoch_D_Loss:0.1013 ||Epoch_G_Loss:0.1420 ||Epoch_E_Loss:0.1715
# timer:  0.2467 sec.
# -------------
# Epoch 1462/1500
# -------------
# （train）
# -------------
# epoch 1462 || Epoch_D_Loss:0.1106 ||Epoch_G_Loss:0.1243 ||Epoch_E_Loss:0.1658
# timer:  0.2225 sec.
# -------------
# Epoch 1463/1500
# -------------
# （train）
# -------------
# epoch 1463 || Epoch_D_Loss:0.1470 ||Epoch_G_Loss:0.1171 ||Epoch_E_Loss:0.1290
# timer:  0.2270 sec.
# -------------
# Epoch 1464/1500
# -------------
# （train）
# -------------
# epoch 1464 || Epoch_D_Loss:0.1266 ||Epoch_G_Loss:0.1197 ||Epoch_E_Loss:0.1436
# timer:  0.2306 sec.
# -------------
# Epoch 1465/1500
# -------------
# （train）
# -------------
# epoch 1465 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1439 ||Epoch_E_Loss:0.1750
# timer:  0.2468 sec.
# -------------
# Epoch 1466/1500
# -------------
# （train）
# -------------
# epoch 1466 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.1589 ||Epoch_E_Loss:0.1822
# timer:  0.2318 sec.
# -------------
# Epoch 1467/1500
# -------------
# （train）
# -------------
# epoch 1467 || Epoch_D_Loss:0.1053 ||Epoch_G_Loss:0.1329 ||Epoch_E_Loss:0.1649
# timer:  0.2297 sec.
# -------------
# Epoch 1468/1500
# -------------
# （train）
# -------------
# epoch 1468 || Epoch_D_Loss:0.1280 ||Epoch_G_Loss:0.1148 ||Epoch_E_Loss:0.1455
# timer:  0.2316 sec.
# -------------
# Epoch 1469/1500
# -------------
# （train）
# -------------
# epoch 1469 || Epoch_D_Loss:0.1274 ||Epoch_G_Loss:0.1352 ||Epoch_E_Loss:0.1347
# timer:  0.2345 sec.
# -------------
# Epoch 1470/1500
# -------------
# （train）
# -------------
# epoch 1470 || Epoch_D_Loss:0.0896 ||Epoch_G_Loss:0.1388 ||Epoch_E_Loss:0.1867
# timer:  0.2314 sec.
# -------------
# Epoch 1471/1500
# -------------
# （train）
# -------------
# epoch 1471 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.1660 ||Epoch_E_Loss:0.1938
# timer:  0.2337 sec.
# -------------
# Epoch 1472/1500
# -------------
# （train）
# -------------
# epoch 1472 || Epoch_D_Loss:0.0905 ||Epoch_G_Loss:0.1657 ||Epoch_E_Loss:0.1718
# timer:  0.2452 sec.
# -------------
# Epoch 1473/1500
# -------------
# （train）
# -------------
# epoch 1473 || Epoch_D_Loss:0.1123 ||Epoch_G_Loss:0.1290 ||Epoch_E_Loss:0.1681
# timer:  0.2313 sec.
# -------------
# Epoch 1474/1500
# -------------
# （train）
# -------------
# epoch 1474 || Epoch_D_Loss:0.1341 ||Epoch_G_Loss:0.1293 ||Epoch_E_Loss:0.1379
# timer:  0.2402 sec.
# -------------
# Epoch 1475/1500
# -------------
# （train）
# -------------
# epoch 1475 || Epoch_D_Loss:0.1125 ||Epoch_G_Loss:0.1281 ||Epoch_E_Loss:0.1522
# timer:  0.2294 sec.
# -------------
# Epoch 1476/1500
# -------------
# （train）
# -------------
# epoch 1476 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1358 ||Epoch_E_Loss:0.1690
# timer:  0.2346 sec.
# -------------
# Epoch 1477/1500
# -------------
# （train）
# -------------
# epoch 1477 || Epoch_D_Loss:0.1022 ||Epoch_G_Loss:0.1334 ||Epoch_E_Loss:0.1696
# timer:  0.2302 sec.
# -------------
# Epoch 1478/1500
# -------------
# （train）
# -------------
# epoch 1478 || Epoch_D_Loss:0.1112 ||Epoch_G_Loss:0.1533 ||Epoch_E_Loss:0.1555
# timer:  0.2503 sec.
# -------------
# Epoch 1479/1500
# -------------
# （train）
# -------------
# epoch 1479 || Epoch_D_Loss:0.0992 ||Epoch_G_Loss:0.1430 ||Epoch_E_Loss:0.1629
# timer:  0.2268 sec.
# -------------
# Epoch 1480/1500
# -------------
# （train）
# -------------
# epoch 1480 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1464 ||Epoch_E_Loss:0.1666
# timer:  0.2313 sec.
# -------------
# Epoch 1481/1500
# -------------
# （train）
# -------------
# epoch 1481 || Epoch_D_Loss:0.1033 ||Epoch_G_Loss:0.1399 ||Epoch_E_Loss:0.1656
# timer:  0.2279 sec.
# -------------
# Epoch 1482/1500
# -------------
# （train）
# -------------
# epoch 1482 || Epoch_D_Loss:0.1108 ||Epoch_G_Loss:0.1438 ||Epoch_E_Loss:0.1513
# timer:  0.2349 sec.
# -------------
# Epoch 1483/1500
# -------------
# （train）
# -------------
# epoch 1483 || Epoch_D_Loss:0.1068 ||Epoch_G_Loss:0.1334 ||Epoch_E_Loss:0.1549
# timer:  0.2393 sec.
# -------------
# Epoch 1484/1500
# -------------
# （train）
# -------------
# epoch 1484 || Epoch_D_Loss:0.1013 ||Epoch_G_Loss:0.1525 ||Epoch_E_Loss:0.1550
# timer:  0.2300 sec.
# -------------
# Epoch 1485/1500
# -------------
# （train）
# -------------
# epoch 1485 || Epoch_D_Loss:0.0953 ||Epoch_G_Loss:0.1363 ||Epoch_E_Loss:0.1736
# timer:  0.2318 sec.
# -------------
# Epoch 1486/1500
# -------------
# （train）
# -------------
# epoch 1486 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.1563 ||Epoch_E_Loss:0.1709
# timer:  0.2328 sec.
# -------------
# Epoch 1487/1500
# -------------
# （train）
# -------------
# epoch 1487 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.1437 ||Epoch_E_Loss:0.1753
# timer:  0.2371 sec.
# -------------
# Epoch 1488/1500
# -------------
# （train）
# -------------
# epoch 1488 || Epoch_D_Loss:0.1018 ||Epoch_G_Loss:0.1460 ||Epoch_E_Loss:0.1638
# timer:  0.2297 sec.
# -------------
# Epoch 1489/1500
# -------------
# （train）
# -------------
# epoch 1489 || Epoch_D_Loss:0.1131 ||Epoch_G_Loss:0.1404 ||Epoch_E_Loss:0.1467
# timer:  0.2331 sec.
# -------------
# Epoch 1490/1500
# -------------
# （train）
# -------------
# epoch 1490 || Epoch_D_Loss:0.1229 ||Epoch_G_Loss:0.1229 ||Epoch_E_Loss:0.1472
# timer:  0.2437 sec.
# -------------
# Epoch 1491/1500
# -------------
# （train）
# -------------
# epoch 1491 || Epoch_D_Loss:0.1222 ||Epoch_G_Loss:0.1304 ||Epoch_E_Loss:0.1505
# timer:  0.2382 sec.
# -------------
# Epoch 1492/1500
# -------------
# （train）
# -------------
# epoch 1492 || Epoch_D_Loss:0.1030 ||Epoch_G_Loss:0.1506 ||Epoch_E_Loss:0.1527
# timer:  0.2316 sec.
# -------------
# Epoch 1493/1500
# -------------
# （train）
# -------------
# epoch 1493 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1461 ||Epoch_E_Loss:0.1742
# timer:  0.2320 sec.
# -------------
# Epoch 1494/1500
# -------------
# （train）
# -------------
# epoch 1494 || Epoch_D_Loss:0.0920 ||Epoch_G_Loss:0.1564 ||Epoch_E_Loss:0.1639
# timer:  0.2324 sec.
# -------------
# Epoch 1495/1500
# -------------
# （train）
# -------------
# epoch 1495 || Epoch_D_Loss:0.0920 ||Epoch_G_Loss:0.1414 ||Epoch_E_Loss:0.1734
# timer:  0.2374 sec.
# -------------
# Epoch 1496/1500
# -------------
# （train）
# -------------
# epoch 1496 || Epoch_D_Loss:0.0967 ||Epoch_G_Loss:0.1536 ||Epoch_E_Loss:0.1551
# timer:  0.2442 sec.
# -------------
# Epoch 1497/1500
# -------------
# （train）
# -------------
# epoch 1497 || Epoch_D_Loss:0.1320 ||Epoch_G_Loss:0.1315 ||Epoch_E_Loss:0.1461
# timer:  0.2360 sec.
# -------------
# Epoch 1498/1500
# -------------
# （train）
# -------------
# epoch 1498 || Epoch_D_Loss:0.1167 ||Epoch_G_Loss:0.1204 ||Epoch_E_Loss:0.1524
# timer:  0.2302 sec.
# -------------
# Epoch 1499/1500
# -------------
# （train）
# -------------
# epoch 1499 || Epoch_D_Loss:0.1136 ||Epoch_G_Loss:0.1528 ||Epoch_E_Loss:0.1381
# timer:  0.2480 sec.
# 総イテレーション回数: 10501

# %%
# 生成画像と訓練データを可視化する
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # テスト画像で異常検知する

# %%
# テスト用のDataLoaderの作成


def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, z_out_real, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量マップを取り出す

    _, x_feature = D(x, z_out_real)
    _, G_feature = D(fake_img, z_out_real)

    # テスト画像xと生成画像fake_imgの特徴量の差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
# 異常検知したい画像
x = imges[0:5]
x = x.to(device)

# 教師データの画像をエンコードしてzにしてから、Gで生成
z_out_real = E_update(imges.to(device))
imges_reconstract = G_update(z_out_real)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, imges_reconstract, z_out_real, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(imges_reconstract[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss： [163. 170. 232. 187. 192.]

# %% [markdown]
# 以上
