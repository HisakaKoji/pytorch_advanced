# %% [markdown]
# # 6.2 AnoGANの作成
#
# - 本ファイルでは、AnoGANのネットワークを実装とAnoGANの学習をします。

# %%
# !git clone https://github.com/HisakaKoji/pytorch_advanced.git
# Out:
# Cloning into 'pytorch_advanced'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 467 (delta 14), reused 0 (delta 0), pack-reused 443
# Receiving objects: 100% (467/467), 15.07 MiB | 25.89 MiB/s, done.
# Resolving deltas: 100% (249/249), done.

# %%
# %cd pytorch_advanced/6_gan_anomaly_detection/
# Out:
# /content/pytorch_advanced/6_gan_anomaly_detection

# %%
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# %%
# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
import sklearn
print(sklearn.__version__)

# AWSのAMIでsklernのversionが0.20より低い場合はバージョンを更新します
# pip install -U scikit-learn
# Out:
# 0.22.2.post1

# %%
# MNISTの手書き数字画像をダウンロードし読み込みます
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  # data_homeは保存先を指定します

# %%
# データの取り出し
X = mnist.data
y = mnist.target

# %%
# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))
# Out:
# この画像データのラベルは5です

# %%
# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1
        
    # 7と8を200枚ずつ作成したらbreak
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count2+=1
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %%
# フォルダ「data」の下にフォルダ「img_78_28size」を作成する
data_dir_path = "./data/img_78_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78_28size」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1
    
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test_28size/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count2+=1 
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %% [markdown]
# # 6.2 学習目標
#
# 1.	AnoGANでテスト画像に最も似た画像を生成するノイズzを求める方法を理解する
# 2.	AnoGANを実装し、手書き数字画像で異常検知が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out[0]))

# feature
print(d_out[1].shape)
# Out:
# tensor([[[[0.5066]]]], grad_fn=<SigmoidBackward>)
# torch.Size([1, 8192])

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習させる

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real, _ = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            # 誤差を計算
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    
    print("総イテレーション回数:", iteration)

    return G, D

# %%
# 学習・検証を実行する
# 8分ほどかかる
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/300
# -------------
# （train）
# /pytorch/aten/src/ATen/native/TensorFactories.cpp:361: UserWarning: Deprecation warning: In a future PyTorch release torch.full will no longer return tensors of floating dtype by default. Instead, a bool fill_value will return a tensor of torch.bool dtype, and an integral fill_value will return a tensor of torch.long dtype. Set the optional `dtype` or `out` arguments to suppress this warning.
# -------------
# epoch 0 || Epoch_D_Loss:0.0689 ||Epoch_G_Loss:0.2649
# timer:  2.2528 sec.
# -------------
# Epoch 1/300
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.5852
# timer:  1.5288 sec.
# -------------
# Epoch 2/300
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.4303 ||Epoch_G_Loss:0.6828
# timer:  1.5372 sec.
# -------------
# Epoch 3/300
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0233 ||Epoch_G_Loss:0.2390
# timer:  1.5419 sec.
# -------------
# Epoch 4/300
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0070 ||Epoch_G_Loss:0.3798
# timer:  1.5316 sec.
# -------------
# Epoch 5/300
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0084 ||Epoch_G_Loss:0.5953
# timer:  1.5272 sec.
# -------------
# Epoch 6/300
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.2835 ||Epoch_G_Loss:0.1693
# timer:  1.5269 sec.
# -------------
# Epoch 7/300
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.3460
# timer:  1.5325 sec.
# -------------
# Epoch 8/300
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0035 ||Epoch_G_Loss:0.3980
# timer:  1.5187 sec.
# -------------
# Epoch 9/300
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.4209 ||Epoch_G_Loss:0.4175
# timer:  1.5127 sec.
# -------------
# Epoch 10/300
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0156 ||Epoch_G_Loss:0.2612
# timer:  1.5216 sec.
# -------------
# Epoch 11/300
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.3539
# timer:  1.5342 sec.
# -------------
# Epoch 12/300
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.2655 ||Epoch_G_Loss:0.2408
# timer:  1.5371 sec.
# -------------
# Epoch 13/300
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0244 ||Epoch_G_Loss:0.2529
# timer:  1.5339 sec.
# -------------
# Epoch 14/300
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.2982
# timer:  1.5379 sec.
# -------------
# Epoch 15/300
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0210 ||Epoch_G_Loss:0.2530
# timer:  1.5284 sec.
# -------------
# Epoch 16/300
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.1444 ||Epoch_G_Loss:0.2350
# timer:  1.5275 sec.
# -------------
# Epoch 17/300
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0218 ||Epoch_G_Loss:0.2624
# timer:  1.5298 sec.
# -------------
# Epoch 18/300
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.1376 ||Epoch_G_Loss:0.2283
# timer:  1.5367 sec.
# -------------
# Epoch 19/300
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0209 ||Epoch_G_Loss:0.2523
# timer:  1.5557 sec.
# -------------
# Epoch 20/300
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.1404 ||Epoch_G_Loss:0.3830
# timer:  1.5392 sec.
# -------------
# Epoch 21/300
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0243 ||Epoch_G_Loss:0.2358
# timer:  1.5381 sec.
# -------------
# Epoch 22/300
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0151 ||Epoch_G_Loss:0.2978
# timer:  1.5426 sec.
# -------------
# Epoch 23/300
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.3116
# timer:  1.5407 sec.
# -------------
# Epoch 24/300
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1722 ||Epoch_G_Loss:0.3685
# timer:  1.5373 sec.
# -------------
# Epoch 25/300
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.1056 ||Epoch_G_Loss:0.2080
# timer:  1.5640 sec.
# -------------
# Epoch 26/300
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0994 ||Epoch_G_Loss:0.1648
# timer:  1.5573 sec.
# -------------
# Epoch 27/300
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.1358 ||Epoch_G_Loss:0.2234
# timer:  1.5450 sec.
# -------------
# Epoch 28/300
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0672 ||Epoch_G_Loss:0.1936
# timer:  1.5396 sec.
# -------------
# Epoch 29/300
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1118 ||Epoch_G_Loss:0.1697
# timer:  1.5518 sec.
# -------------
# Epoch 30/300
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.1098 ||Epoch_G_Loss:0.1732
# timer:  1.5799 sec.
# -------------
# Epoch 31/300
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.1049 ||Epoch_G_Loss:0.1675
# timer:  1.5503 sec.
# -------------
# Epoch 32/300
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1632
# timer:  1.5517 sec.
# -------------
# Epoch 33/300
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1042 ||Epoch_G_Loss:0.1688
# timer:  1.5578 sec.
# -------------
# Epoch 34/300
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1684
# timer:  1.5603 sec.
# -------------
# Epoch 35/300
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.1610
# timer:  1.5697 sec.
# -------------
# Epoch 36/300
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1072 ||Epoch_G_Loss:0.1639
# timer:  1.5401 sec.
# -------------
# Epoch 37/300
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.1034 ||Epoch_G_Loss:0.1977
# timer:  1.5402 sec.
# -------------
# Epoch 38/300
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1177 ||Epoch_G_Loss:0.1427
# timer:  1.5485 sec.
# -------------
# Epoch 39/300
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.1281
# timer:  1.5742 sec.
# -------------
# Epoch 40/300
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.1082 ||Epoch_G_Loss:0.1721
# timer:  1.5609 sec.
# -------------
# Epoch 41/300
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.1201 ||Epoch_G_Loss:0.1360
# timer:  1.5565 sec.
# -------------
# Epoch 42/300
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1302
# timer:  1.5559 sec.
# -------------
# Epoch 43/300
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.1566
# timer:  1.5722 sec.
# -------------
# Epoch 44/300
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.1559 ||Epoch_G_Loss:0.1292
# timer:  1.5886 sec.
# -------------
# Epoch 45/300
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1126 ||Epoch_G_Loss:0.1352
# timer:  1.5603 sec.
# -------------
# Epoch 46/300
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.1233 ||Epoch_G_Loss:0.1423
# timer:  1.5600 sec.
# -------------
# Epoch 47/300
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1148 ||Epoch_G_Loss:0.1065
# timer:  1.5721 sec.
# -------------
# Epoch 48/300
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1232 ||Epoch_G_Loss:0.1362
# timer:  1.5724 sec.
# -------------
# Epoch 49/300
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1342 ||Epoch_G_Loss:0.1204
# timer:  1.5648 sec.
# -------------
# Epoch 50/300
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1286 ||Epoch_G_Loss:0.1429
# timer:  1.5714 sec.
# -------------
# Epoch 51/300
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1210 ||Epoch_G_Loss:0.1138
# timer:  1.5970 sec.
# -------------
# Epoch 52/300
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1132 ||Epoch_G_Loss:0.1334
# timer:  1.5695 sec.
# -------------
# Epoch 53/300
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1196 ||Epoch_G_Loss:0.1168
# timer:  1.5594 sec.
# -------------
# Epoch 54/300
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1218 ||Epoch_G_Loss:0.1267
# timer:  1.6004 sec.
# -------------
# Epoch 55/300
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1216 ||Epoch_G_Loss:0.1210
# timer:  1.5718 sec.
# -------------
# Epoch 56/300
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.1433
# timer:  1.5654 sec.
# -------------
# Epoch 57/300
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1394 ||Epoch_G_Loss:0.1167
# timer:  1.5658 sec.
# -------------
# Epoch 58/300
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1109 ||Epoch_G_Loss:0.1077
# timer:  1.5888 sec.
# -------------
# Epoch 59/300
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1492 ||Epoch_G_Loss:0.1177
# timer:  1.5728 sec.
# -------------
# Epoch 60/300
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1314
# timer:  1.5585 sec.
# -------------
# Epoch 61/300
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1182 ||Epoch_G_Loss:0.1242
# timer:  1.5781 sec.
# -------------
# Epoch 62/300
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.1169 ||Epoch_G_Loss:0.1151
# timer:  1.5826 sec.
# -------------
# Epoch 63/300
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.1109 ||Epoch_G_Loss:0.1427
# timer:  1.5614 sec.
# -------------
# Epoch 64/300
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1097 ||Epoch_G_Loss:0.1390
# timer:  1.5672 sec.
# -------------
# Epoch 65/300
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1400
# timer:  1.5881 sec.
# -------------
# Epoch 66/300
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.1461
# timer:  1.5729 sec.
# -------------
# Epoch 67/300
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0989 ||Epoch_G_Loss:0.1294
# timer:  1.5710 sec.
# -------------
# Epoch 68/300
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.1274 ||Epoch_G_Loss:0.1737
# timer:  1.5941 sec.
# -------------
# Epoch 69/300
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0870 ||Epoch_G_Loss:0.1418
# timer:  1.5771 sec.
# -------------
# Epoch 70/300
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0976 ||Epoch_G_Loss:0.1497
# timer:  1.5771 sec.
# -------------
# Epoch 71/300
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.0972 ||Epoch_G_Loss:0.1687
# timer:  1.5745 sec.
# -------------
# Epoch 72/300
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.1050 ||Epoch_G_Loss:0.1674
# timer:  1.5892 sec.
# -------------
# Epoch 73/300
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.1606
# timer:  1.5699 sec.
# -------------
# Epoch 74/300
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.1093 ||Epoch_G_Loss:0.1699
# timer:  1.6021 sec.
# -------------
# Epoch 75/300
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0977 ||Epoch_G_Loss:0.1640
# timer:  1.5701 sec.
# -------------
# Epoch 76/300
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0886 ||Epoch_G_Loss:0.1672
# timer:  1.5723 sec.
# -------------
# Epoch 77/300
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.1001 ||Epoch_G_Loss:0.1548
# timer:  1.5740 sec.
# -------------
# Epoch 78/300
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0920 ||Epoch_G_Loss:0.1778
# timer:  1.5997 sec.
# -------------
# Epoch 79/300
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0891 ||Epoch_G_Loss:0.1498
# timer:  1.5678 sec.
# -------------
# Epoch 80/300
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.1069 ||Epoch_G_Loss:0.1817
# timer:  1.5718 sec.
# -------------
# Epoch 81/300
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0902 ||Epoch_G_Loss:0.1705
# timer:  1.6181 sec.
# -------------
# Epoch 82/300
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0807 ||Epoch_G_Loss:0.1840
# timer:  1.5735 sec.
# -------------
# Epoch 83/300
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.1021 ||Epoch_G_Loss:0.1590
# timer:  1.5831 sec.
# -------------
# Epoch 84/300
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1809
# timer:  1.5892 sec.
# -------------
# Epoch 85/300
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0795 ||Epoch_G_Loss:0.1754
# timer:  1.5768 sec.
# -------------
# Epoch 86/300
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1996
# timer:  1.5729 sec.
# -------------
# Epoch 87/300
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0843 ||Epoch_G_Loss:0.1711
# timer:  1.6007 sec.
# -------------
# Epoch 88/300
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.2178
# timer:  1.5579 sec.
# -------------
# Epoch 89/300
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0817 ||Epoch_G_Loss:0.1664
# timer:  1.5600 sec.
# -------------
# Epoch 90/300
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0990 ||Epoch_G_Loss:0.1810
# timer:  1.5680 sec.
# -------------
# Epoch 91/300
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1938
# timer:  1.5776 sec.
# -------------
# Epoch 92/300
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0824 ||Epoch_G_Loss:0.1505
# timer:  1.5632 sec.
# -------------
# Epoch 93/300
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0952 ||Epoch_G_Loss:0.1792
# timer:  1.5674 sec.
# -------------
# Epoch 94/300
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0934 ||Epoch_G_Loss:0.2013
# timer:  1.5857 sec.
# -------------
# Epoch 95/300
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0651 ||Epoch_G_Loss:0.1823
# timer:  1.5919 sec.
# -------------
# Epoch 96/300
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.1129 ||Epoch_G_Loss:0.2068
# timer:  1.5801 sec.
# -------------
# Epoch 97/300
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1889
# timer:  1.5937 sec.
# -------------
# Epoch 98/300
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0734 ||Epoch_G_Loss:0.2095
# timer:  1.5870 sec.
# -------------
# Epoch 99/300
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1698
# timer:  1.5848 sec.
# -------------
# Epoch 100/300
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0968 ||Epoch_G_Loss:0.1921
# timer:  1.5928 sec.
# -------------
# Epoch 101/300
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0723 ||Epoch_G_Loss:0.2160
# timer:  1.5755 sec.
# -------------
# Epoch 102/300
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0926 ||Epoch_G_Loss:0.1792
# timer:  1.5783 sec.
# -------------
# Epoch 103/300
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0880 ||Epoch_G_Loss:0.2049
# timer:  1.6115 sec.
# -------------
# Epoch 104/300
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.1870
# timer:  1.5698 sec.
# -------------
# Epoch 105/300
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.1897
# timer:  1.5754 sec.
# -------------
# Epoch 106/300
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0941 ||Epoch_G_Loss:0.2248
# timer:  1.6058 sec.
# -------------
# Epoch 107/300
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.1898
# timer:  1.5752 sec.
# -------------
# Epoch 108/300
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0879 ||Epoch_G_Loss:0.1896
# timer:  1.5730 sec.
# -------------
# Epoch 109/300
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0707 ||Epoch_G_Loss:0.2120
# timer:  1.5969 sec.
# -------------
# Epoch 110/300
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0806 ||Epoch_G_Loss:0.1904
# timer:  1.5783 sec.
# -------------
# Epoch 111/300
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0905 ||Epoch_G_Loss:0.2093
# timer:  1.5633 sec.
# -------------
# Epoch 112/300
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0573 ||Epoch_G_Loss:0.2476
# timer:  1.5716 sec.
# -------------
# Epoch 113/300
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.1761
# timer:  1.5808 sec.
# -------------
# Epoch 114/300
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0715 ||Epoch_G_Loss:0.2192
# timer:  1.5657 sec.
# -------------
# Epoch 115/300
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0855 ||Epoch_G_Loss:0.1997
# timer:  1.5611 sec.
# -------------
# Epoch 116/300
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.2255
# timer:  1.5880 sec.
# -------------
# Epoch 117/300
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0674 ||Epoch_G_Loss:0.2385
# timer:  1.5777 sec.
# -------------
# Epoch 118/300
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0826 ||Epoch_G_Loss:0.1978
# timer:  1.5732 sec.
# -------------
# Epoch 119/300
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0750 ||Epoch_G_Loss:0.2248
# timer:  1.5996 sec.
# -------------
# Epoch 120/300
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0747 ||Epoch_G_Loss:0.1999
# timer:  1.5703 sec.
# -------------
# Epoch 121/300
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.2357
# timer:  1.5715 sec.
# -------------
# Epoch 122/300
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0750 ||Epoch_G_Loss:0.2167
# timer:  1.5653 sec.
# -------------
# Epoch 123/300
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0779 ||Epoch_G_Loss:0.2274
# timer:  1.5929 sec.
# -------------
# Epoch 124/300
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.2343
# timer:  1.5677 sec.
# -------------
# Epoch 125/300
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.2433
# timer:  1.5617 sec.
# -------------
# Epoch 126/300
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0628 ||Epoch_G_Loss:0.2058
# timer:  1.5904 sec.
# -------------
# Epoch 127/300
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0747 ||Epoch_G_Loss:0.2459
# timer:  1.5839 sec.
# -------------
# Epoch 128/300
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0722 ||Epoch_G_Loss:0.2443
# timer:  1.5718 sec.
# -------------
# Epoch 129/300
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0678 ||Epoch_G_Loss:0.2539
# timer:  1.5956 sec.
# -------------
# Epoch 130/300
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0507 ||Epoch_G_Loss:0.2575
# timer:  1.5750 sec.
# -------------
# Epoch 131/300
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.2295
# timer:  1.5703 sec.
# -------------
# Epoch 132/300
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0484 ||Epoch_G_Loss:0.2796
# timer:  1.5784 sec.
# -------------
# Epoch 133/300
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0772 ||Epoch_G_Loss:0.2075
# timer:  1.5979 sec.
# -------------
# Epoch 134/300
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.2593
# timer:  1.5728 sec.
# -------------
# Epoch 135/300
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0489 ||Epoch_G_Loss:0.2800
# timer:  1.5724 sec.
# -------------
# Epoch 136/300
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0727 ||Epoch_G_Loss:0.2537
# timer:  1.5903 sec.
# -------------
# Epoch 137/300
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0504 ||Epoch_G_Loss:0.2557
# timer:  1.5701 sec.
# -------------
# Epoch 138/300
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2878
# timer:  1.5700 sec.
# -------------
# Epoch 139/300
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0767 ||Epoch_G_Loss:0.2456
# timer:  1.6053 sec.
# -------------
# Epoch 140/300
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0395 ||Epoch_G_Loss:0.2728
# timer:  1.5620 sec.
# -------------
# Epoch 141/300
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0815 ||Epoch_G_Loss:0.2586
# timer:  1.5735 sec.
# -------------
# Epoch 142/300
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0690 ||Epoch_G_Loss:0.2885
# timer:  1.5885 sec.
# -------------
# Epoch 143/300
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0524 ||Epoch_G_Loss:0.2796
# timer:  1.5684 sec.
# -------------
# Epoch 144/300
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.2698
# timer:  1.5726 sec.
# -------------
# Epoch 145/300
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0450 ||Epoch_G_Loss:0.3114
# timer:  1.5632 sec.
# -------------
# Epoch 146/300
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0621 ||Epoch_G_Loss:0.2821
# timer:  1.5851 sec.
# -------------
# Epoch 147/300
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0481 ||Epoch_G_Loss:0.2981
# timer:  1.5566 sec.
# -------------
# Epoch 148/300
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.3072
# timer:  1.5723 sec.
# -------------
# Epoch 149/300
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0515 ||Epoch_G_Loss:0.2997
# timer:  1.5933 sec.
# -------------
# Epoch 150/300
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0594 ||Epoch_G_Loss:0.2946
# timer:  1.5877 sec.
# -------------
# Epoch 151/300
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.3280
# timer:  1.5804 sec.
# -------------
# Epoch 152/300
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0787 ||Epoch_G_Loss:0.2772
# timer:  1.5943 sec.
# -------------
# Epoch 153/300
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0401 ||Epoch_G_Loss:0.3365
# timer:  1.5774 sec.
# -------------
# Epoch 154/300
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0614 ||Epoch_G_Loss:0.2715
# timer:  1.5650 sec.
# -------------
# Epoch 155/300
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0480 ||Epoch_G_Loss:0.3379
# timer:  1.6029 sec.
# -------------
# Epoch 156/300
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0496 ||Epoch_G_Loss:0.2852
# timer:  1.5788 sec.
# -------------
# Epoch 157/300
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0531 ||Epoch_G_Loss:0.3217
# timer:  1.5914 sec.
# -------------
# Epoch 158/300
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.3127
# timer:  1.5980 sec.
# -------------
# Epoch 159/300
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0563 ||Epoch_G_Loss:0.3204
# timer:  1.5808 sec.
# -------------
# Epoch 160/300
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0486 ||Epoch_G_Loss:0.3221
# timer:  1.5812 sec.
# -------------
# Epoch 161/300
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0422 ||Epoch_G_Loss:0.3341
# timer:  1.6008 sec.
# -------------
# Epoch 162/300
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0568 ||Epoch_G_Loss:0.3292
# timer:  1.5783 sec.
# -------------
# Epoch 163/300
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0434 ||Epoch_G_Loss:0.3032
# timer:  1.5710 sec.
# -------------
# Epoch 164/300
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0427 ||Epoch_G_Loss:0.3518
# timer:  1.5858 sec.
# -------------
# Epoch 165/300
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0492 ||Epoch_G_Loss:0.3111
# timer:  1.5648 sec.
# -------------
# Epoch 166/300
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0454 ||Epoch_G_Loss:0.3715
# timer:  1.5596 sec.
# -------------
# Epoch 167/300
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0343 ||Epoch_G_Loss:0.3204
# timer:  1.5720 sec.
# -------------
# Epoch 168/300
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.1374 ||Epoch_G_Loss:0.3545
# timer:  1.5866 sec.
# -------------
# Epoch 169/300
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0290 ||Epoch_G_Loss:0.3021
# timer:  1.5623 sec.
# -------------
# Epoch 170/300
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0524 ||Epoch_G_Loss:0.3337
# timer:  1.5635 sec.
# -------------
# Epoch 171/300
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0334 ||Epoch_G_Loss:0.3492
# timer:  1.5870 sec.
# -------------
# Epoch 172/300
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.3554
# timer:  1.5789 sec.
# -------------
# Epoch 173/300
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0433 ||Epoch_G_Loss:0.2945
# timer:  1.5643 sec.
# -------------
# Epoch 174/300
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0424 ||Epoch_G_Loss:0.3838
# timer:  1.5748 sec.
# -------------
# Epoch 175/300
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0265 ||Epoch_G_Loss:0.3756
# timer:  1.5856 sec.
# -------------
# Epoch 176/300
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0569 ||Epoch_G_Loss:0.3601
# timer:  1.5676 sec.
# -------------
# Epoch 177/300
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0353 ||Epoch_G_Loss:0.3581
# timer:  1.5670 sec.
# -------------
# Epoch 178/300
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0347 ||Epoch_G_Loss:0.3808
# timer:  1.6011 sec.
# -------------
# Epoch 179/300
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0465 ||Epoch_G_Loss:0.3489
# timer:  1.5745 sec.
# -------------
# Epoch 180/300
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0514 ||Epoch_G_Loss:0.3935
# timer:  1.5676 sec.
# -------------
# Epoch 181/300
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0233 ||Epoch_G_Loss:0.3784
# timer:  1.5959 sec.
# -------------
# Epoch 182/300
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.3941
# timer:  1.5904 sec.
# -------------
# Epoch 183/300
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0282 ||Epoch_G_Loss:0.3289
# timer:  1.5607 sec.
# -------------
# Epoch 184/300
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0447 ||Epoch_G_Loss:0.3674
# timer:  1.6004 sec.
# -------------
# Epoch 185/300
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0336 ||Epoch_G_Loss:0.3549
# timer:  1.5731 sec.
# -------------
# Epoch 186/300
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0383 ||Epoch_G_Loss:0.4097
# timer:  1.5757 sec.
# -------------
# Epoch 187/300
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0279 ||Epoch_G_Loss:0.3578
# timer:  1.5775 sec.
# -------------
# Epoch 188/300
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0679 ||Epoch_G_Loss:0.3684
# timer:  1.5872 sec.
# -------------
# Epoch 189/300
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0179 ||Epoch_G_Loss:0.3838
# timer:  1.5734 sec.
# -------------
# Epoch 190/300
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0548 ||Epoch_G_Loss:0.3637
# timer:  1.5692 sec.
# -------------
# Epoch 191/300
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0344 ||Epoch_G_Loss:0.3978
# timer:  1.6002 sec.
# -------------
# Epoch 192/300
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.4016
# timer:  1.5706 sec.
# -------------
# Epoch 193/300
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0500 ||Epoch_G_Loss:0.3935
# timer:  1.5811 sec.
# -------------
# Epoch 194/300
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0362 ||Epoch_G_Loss:0.4591
# timer:  1.5949 sec.
# -------------
# Epoch 195/300
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.4806
# timer:  1.5651 sec.
# -------------
# Epoch 196/300
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.3091
# timer:  1.5622 sec.
# -------------
# Epoch 197/300
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0310 ||Epoch_G_Loss:0.4044
# timer:  1.5673 sec.
# -------------
# Epoch 198/300
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.4045
# timer:  1.5843 sec.
# -------------
# Epoch 199/300
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0637 ||Epoch_G_Loss:0.3861
# timer:  1.5650 sec.
# -------------
# Epoch 200/300
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.0184 ||Epoch_G_Loss:0.4274
# timer:  1.5547 sec.
# -------------
# Epoch 201/300
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.3744
# timer:  1.5595 sec.
# -------------
# Epoch 202/300
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.0432 ||Epoch_G_Loss:0.4158
# timer:  1.5909 sec.
# -------------
# Epoch 203/300
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.0245 ||Epoch_G_Loss:0.4165
# timer:  1.5702 sec.
# -------------
# Epoch 204/300
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.0116 ||Epoch_G_Loss:0.4922
# timer:  1.5697 sec.
# -------------
# Epoch 205/300
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.0658 ||Epoch_G_Loss:0.4161
# timer:  1.6076 sec.
# -------------
# Epoch 206/300
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.0200 ||Epoch_G_Loss:0.3946
# timer:  1.5749 sec.
# -------------
# Epoch 207/300
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.0297 ||Epoch_G_Loss:0.5024
# timer:  1.5730 sec.
# -------------
# Epoch 208/300
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.0508 ||Epoch_G_Loss:0.3558
# timer:  1.5976 sec.
# -------------
# Epoch 209/300
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0275 ||Epoch_G_Loss:0.4517
# timer:  1.5708 sec.
# -------------
# Epoch 210/300
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.0395 ||Epoch_G_Loss:0.4365
# timer:  1.5710 sec.
# -------------
# Epoch 211/300
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.0290 ||Epoch_G_Loss:0.4863
# timer:  1.6052 sec.
# -------------
# Epoch 212/300
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.0432 ||Epoch_G_Loss:0.3596
# timer:  1.5842 sec.
# -------------
# Epoch 213/300
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.0099 ||Epoch_G_Loss:0.5313
# timer:  1.5674 sec.
# -------------
# Epoch 214/300
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.0695 ||Epoch_G_Loss:0.4120
# timer:  1.6022 sec.
# -------------
# Epoch 215/300
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.0130 ||Epoch_G_Loss:0.4497
# timer:  1.5695 sec.
# -------------
# Epoch 216/300
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.0502 ||Epoch_G_Loss:0.4462
# timer:  1.5706 sec.
# -------------
# Epoch 217/300
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.0126 ||Epoch_G_Loss:0.4556
# timer:  1.5963 sec.
# -------------
# Epoch 218/300
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.0099 ||Epoch_G_Loss:0.5661
# timer:  1.5655 sec.
# -------------
# Epoch 219/300
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.0657 ||Epoch_G_Loss:0.3276
# timer:  1.5634 sec.
# -------------
# Epoch 220/300
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.0238 ||Epoch_G_Loss:0.4667
# timer:  1.5606 sec.
# -------------
# Epoch 221/300
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.0134 ||Epoch_G_Loss:0.5039
# timer:  1.5881 sec.
# -------------
# Epoch 222/300
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.0383 ||Epoch_G_Loss:0.4855
# timer:  1.5632 sec.
# -------------
# Epoch 223/300
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.0163 ||Epoch_G_Loss:0.4954
# timer:  1.5641 sec.
# -------------
# Epoch 224/300
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.0383 ||Epoch_G_Loss:0.4583
# timer:  1.5713 sec.
# -------------
# Epoch 225/300
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.5650
# timer:  1.5901 sec.
# -------------
# Epoch 226/300
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.0679 ||Epoch_G_Loss:0.4595
# timer:  1.5701 sec.
# -------------
# Epoch 227/300
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.0156 ||Epoch_G_Loss:0.4811
# timer:  1.5623 sec.
# -------------
# Epoch 228/300
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.0343 ||Epoch_G_Loss:0.4290
# timer:  1.5905 sec.
# -------------
# Epoch 229/300
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.0279 ||Epoch_G_Loss:0.5060
# timer:  1.5705 sec.
# -------------
# Epoch 230/300
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.5550
# timer:  1.5670 sec.
# -------------
# Epoch 231/300
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.0629 ||Epoch_G_Loss:0.4139
# timer:  1.6040 sec.
# -------------
# Epoch 232/300
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.0112 ||Epoch_G_Loss:0.5023
# timer:  1.5718 sec.
# -------------
# Epoch 233/300
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.0181 ||Epoch_G_Loss:0.5515
# timer:  1.5767 sec.
# -------------
# Epoch 234/300
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.3442
# timer:  1.5840 sec.
# -------------
# Epoch 235/300
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.0105 ||Epoch_G_Loss:0.5975
# timer:  1.5885 sec.
# -------------
# Epoch 236/300
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.0602 ||Epoch_G_Loss:0.4944
# timer:  1.5615 sec.
# -------------
# Epoch 237/300
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.0150 ||Epoch_G_Loss:0.4716
# timer:  1.5749 sec.
# -------------
# Epoch 238/300
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.0157 ||Epoch_G_Loss:0.6284
# timer:  1.5972 sec.
# -------------
# Epoch 239/300
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.0334 ||Epoch_G_Loss:0.4588
# timer:  1.5749 sec.
# -------------
# Epoch 240/300
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.0122 ||Epoch_G_Loss:0.5397
# timer:  1.5722 sec.
# -------------
# Epoch 241/300
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.0313 ||Epoch_G_Loss:0.5181
# timer:  1.5914 sec.
# -------------
# Epoch 242/300
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.0373 ||Epoch_G_Loss:0.5662
# timer:  1.5713 sec.
# -------------
# Epoch 243/300
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.0308 ||Epoch_G_Loss:0.4190
# timer:  1.5644 sec.
# -------------
# Epoch 244/300
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.0441 ||Epoch_G_Loss:0.4941
# timer:  1.5924 sec.
# -------------
# Epoch 245/300
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.0139 ||Epoch_G_Loss:0.4883
# timer:  1.5742 sec.
# -------------
# Epoch 246/300
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.0077 ||Epoch_G_Loss:0.6003
# timer:  1.5689 sec.
# -------------
# Epoch 247/300
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.0487 ||Epoch_G_Loss:0.5510
# timer:  1.5916 sec.
# -------------
# Epoch 248/300
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.0201 ||Epoch_G_Loss:0.4744
# timer:  1.5993 sec.
# -------------
# Epoch 249/300
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.0113 ||Epoch_G_Loss:0.6104
# timer:  1.5532 sec.
# -------------
# Epoch 250/300
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.0469 ||Epoch_G_Loss:0.5331
# timer:  1.5639 sec.
# -------------
# Epoch 251/300
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.0224 ||Epoch_G_Loss:0.5473
# timer:  1.5787 sec.
# -------------
# Epoch 252/300
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.0130 ||Epoch_G_Loss:0.5124
# timer:  1.5623 sec.
# -------------
# Epoch 253/300
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.0338 ||Epoch_G_Loss:0.4775
# timer:  1.5581 sec.
# -------------
# Epoch 254/300
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.6199
# timer:  1.5671 sec.
# -------------
# Epoch 255/300
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.4995
# timer:  1.5921 sec.
# -------------
# Epoch 256/300
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.0143 ||Epoch_G_Loss:0.6112
# timer:  1.5715 sec.
# -------------
# Epoch 257/300
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.0260 ||Epoch_G_Loss:0.5393
# timer:  1.5635 sec.
# -------------
# Epoch 258/300
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.0527 ||Epoch_G_Loss:0.3925
# timer:  1.6027 sec.
# -------------
# Epoch 259/300
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.5425
# timer:  1.5722 sec.
# -------------
# Epoch 260/300
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.0373 ||Epoch_G_Loss:0.5595
# timer:  1.5782 sec.
# -------------
# Epoch 261/300
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.0099 ||Epoch_G_Loss:0.5650
# timer:  1.5959 sec.
# -------------
# Epoch 262/300
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.6035
# timer:  1.5767 sec.
# -------------
# Epoch 263/300
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.0467 ||Epoch_G_Loss:0.4711
# timer:  1.5745 sec.
# -------------
# Epoch 264/300
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.0071 ||Epoch_G_Loss:0.5776
# timer:  1.5943 sec.
# -------------
# Epoch 265/300
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.7348
# timer:  1.5721 sec.
# -------------
# Epoch 266/300
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.0935 ||Epoch_G_Loss:0.3502
# timer:  1.5852 sec.
# -------------
# Epoch 267/300
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.0101 ||Epoch_G_Loss:0.4968
# timer:  1.5720 sec.
# -------------
# Epoch 268/300
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.5699
# timer:  1.5865 sec.
# -------------
# Epoch 269/300
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.6671
# timer:  1.5569 sec.
# -------------
# Epoch 270/300
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.0655 ||Epoch_G_Loss:0.3893
# timer:  1.5621 sec.
# -------------
# Epoch 271/300
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.0094 ||Epoch_G_Loss:0.5339
# timer:  1.5888 sec.
# -------------
# Epoch 272/300
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.7067
# timer:  1.5691 sec.
# -------------
# Epoch 273/300
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.4042
# timer:  1.5644 sec.
# -------------
# Epoch 274/300
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.0075 ||Epoch_G_Loss:0.5522
# timer:  1.5738 sec.
# -------------
# Epoch 275/300
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.0037 ||Epoch_G_Loss:0.6597
# timer:  1.5784 sec.
# -------------
# Epoch 276/300
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.0034 ||Epoch_G_Loss:0.7614
# timer:  1.5653 sec.
# -------------
# Epoch 277/300
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.0721 ||Epoch_G_Loss:0.4170
# timer:  1.5582 sec.
# -------------
# Epoch 278/300
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.5850
# timer:  1.5742 sec.
# -------------
# Epoch 279/300
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.6509
# timer:  1.5913 sec.
# -------------
# Epoch 280/300
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.0374 ||Epoch_G_Loss:0.6493
# timer:  1.5609 sec.
# -------------
# Epoch 281/300
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.0301 ||Epoch_G_Loss:0.4221
# timer:  1.5974 sec.
# -------------
# Epoch 282/300
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.5821
# timer:  1.5858 sec.
# -------------
# Epoch 283/300
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.0331 ||Epoch_G_Loss:0.6516
# timer:  1.5758 sec.
# -------------
# Epoch 284/300
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.0331 ||Epoch_G_Loss:0.4547
# timer:  1.5654 sec.
# -------------
# Epoch 285/300
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.6287
# timer:  1.6021 sec.
# -------------
# Epoch 286/300
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.0068 ||Epoch_G_Loss:0.6893
# timer:  1.5737 sec.
# -------------
# Epoch 287/300
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.0025 ||Epoch_G_Loss:0.7657
# timer:  1.5751 sec.
# -------------
# Epoch 288/300
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.0438 ||Epoch_G_Loss:0.7072
# timer:  1.5841 sec.
# -------------
# Epoch 289/300
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.0107 ||Epoch_G_Loss:0.5442
# timer:  1.5769 sec.
# -------------
# Epoch 290/300
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.0130 ||Epoch_G_Loss:0.7261
# timer:  1.5709 sec.
# -------------
# Epoch 291/300
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.0270 ||Epoch_G_Loss:0.5465
# timer:  1.5886 sec.
# -------------
# Epoch 292/300
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.7342
# timer:  1.5895 sec.
# -------------
# Epoch 293/300
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.0355 ||Epoch_G_Loss:0.5252
# timer:  1.5706 sec.
# -------------
# Epoch 294/300
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.0171 ||Epoch_G_Loss:0.6536
# timer:  1.5989 sec.
# -------------
# Epoch 295/300
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.0154 ||Epoch_G_Loss:0.6165
# timer:  1.5707 sec.
# -------------
# Epoch 296/300
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.0041 ||Epoch_G_Loss:0.6974
# timer:  1.5661 sec.
# -------------
# Epoch 297/300
# -------------
# （train）
# -------------
# epoch 297 || Epoch_D_Loss:0.0564 ||Epoch_G_Loss:0.5678
# timer:  1.5944 sec.
# -------------
# Epoch 298/300
# -------------
# （train）
# -------------
# epoch 298 || Epoch_D_Loss:0.0069 ||Epoch_G_Loss:0.6589
# timer:  1.5821 sec.
# -------------
# Epoch 299/300
# -------------
# （train）
# -------------
# epoch 299 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.7241
# timer:  1.5677 sec.
# 総イテレーション回数: 2101

# %%
# 生成画像と訓練データを可視化する
# 本セルは何度か実行し直しています。

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # AnoGANの本体

# %%
def Anomaly_score(x, fake_img, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量を取り出す
    _, x_feature = D(x)
    _, G_feature = D(fake_img)

    # テスト画像xと生成画像fake_imgの特徴量の差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %% [markdown]
# # テスト画像で異常検知する

# %%
# テスト用のDataLoaderの作成


def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イテレータに変換
imges = next(batch_iterator)  

# 1番目のミニバッチを取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
# 異常検知したい画像
x = imges[0:5]
x = x.to(device)

# 異常検知したい画像を生成するための、初期乱数
z = torch.randn(5, 20).to(device)
z = z.view(z.size(0), z.size(1), 1, 1)

# 変数zを微分を求めることが可能なように、requires_gradをTrueに設定
z.requires_grad = True

# 変数zを更新できるように、zの最適化関数を求める
z_optimizer = torch.optim.Adam([z], lr=1e-3)


# zを求める
for epoch in range(5000+1):
    fake_img = G_update(z)
    loss, _, _ = Anomaly_score(x, fake_img, D_update, Lambda=0.1)

    z_optimizer.zero_grad()
    loss.backward()
    z_optimizer.step()

    if epoch % 1000 == 0:
        print('epoch {} || loss_total:{:.0f} '.format(epoch, loss.item()))
# Out:
# epoch 0 || loss_total:6759
# epoch 1000 || loss_total:4754
# epoch 2000 || loss_total:3989
# epoch 3000 || loss_total:3679
# epoch 4000 || loss_total:2868
# epoch 5000 || loss_total:2294

# %%
# 画像を生成
fake_img = G_update(z)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, fake_img, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段にテストデータを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_img[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss： [342. 346. 778. 435. 393.]

# %% [markdown]
# 以上
